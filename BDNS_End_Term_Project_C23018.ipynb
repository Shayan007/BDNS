# %% [markdown]
# <a href="https://colab.research.google.com/github/Shayan007/BDNS/blob/main/BDNS_End_Term_Project_C23018.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pymongo
# Out:
# Requirement already satisfied: pymongo in /usr/local/lib/python3.10/dist-packages (4.4.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from pymongo) (2.3.0)

# %%
import pandas as pd
import numpy as np
import pymongo
import json

# %%
xy=pd.read_csv("cardekho.csv")

# %% [markdown]
# #Reading the Data and Converting the Same to Dictionary

# %%
data=xy.to_dict(orient="records")
data
# Out:
# [{'Car_Name': 'Maruti 800 AC',
#   'Year': 2007,
#   'Selling_Price': 60000,
#   'Kms_Driven': 70000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Wagon R LXI Minor',
#   'Year': 2007,
#   'Selling_Price': 135000,
#   'Kms_Driven': 50000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Verna 1.6 SX',
#   'Year': 2012,
#   'Selling_Price': 600000,
#   'Kms_Driven': 100000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Datsun RediGO T Option',
#   'Year': 2017,
#   'Selling_Price': 250000,
#   'Kms_Driven': 46000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Honda Amaze VX i-DTEC',
#   'Year': 2014,
#   'Selling_Price': 450000,
#   'Kms_Driven': 141000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Maruti Alto LX BSIII',
#   'Year': 2007,
#   'Selling_Price': 140000,
#   'Kms_Driven': 125000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Xcent 1.2 Kappa S',
#   'Year': 2016,
#   'Selling_Price': 550000,
#   'Kms_Driven': 25000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Tata Indigo Grand Petrol',
#   'Year': 2014,
#   'Selling_Price': 240000,
#   'Kms_Driven': 60000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Hyundai Creta 1.6 VTVT S',
#   'Year': 2015,
#   'Selling_Price': 850000,
#   'Kms_Driven': 25000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Celerio Green VXI',
#   'Year': 2017,
#   'Selling_Price': 365000,
#   'Kms_Driven': 78000,
#   'Fuel_Type': 'CNG',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Chevrolet Sail 1.2 Base',
#   'Year': 2015,
#   'Selling_Price': 260000,
#   'Kms_Driven': 35000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Tata Indigo Grand Petrol',
#   'Year': 2014,
#   'Selling_Price': 250000,
#   'Kms_Driven': 100000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Toyota Corolla Altis 1.8 VL CVT',
#   'Year': 2018,
#   'Selling_Price': 1650000,
#   'Kms_Driven': 25000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti 800 AC',
#   'Year': 2007,
#   'Selling_Price': 60000,
#   'Kms_Driven': 70000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Wagon R LXI Minor',
#   'Year': 2007,
#   'Selling_Price': 135000,
#   'Kms_Driven': 50000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Verna 1.6 SX',
#   'Year': 2012,
#   'Selling_Price': 600000,
#   'Kms_Driven': 100000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Datsun RediGO T Option',
#   'Year': 2017,
#   'Selling_Price': 250000,
#   'Kms_Driven': 46000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Honda Amaze VX i-DTEC',
#   'Year': 2014,
#   'Selling_Price': 450000,
#   'Kms_Driven': 141000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Maruti Alto LX BSIII',
#   'Year': 2007,
#   'Selling_Price': 140000,
#   'Kms_Driven': 125000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Xcent 1.2 Kappa S',
#   'Year': 2016,
#   'Selling_Price': 550000,
#   'Kms_Driven': 25000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Tata Indigo Grand Petrol',
#   'Year': 2014,
#   'Selling_Price': 240000,
#   'Kms_Driven': 60000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Hyundai Creta 1.6 VTVT S',
#   'Year': 2015,
#   'Selling_Price': 850000,
#   'Kms_Driven': 25000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Celerio Green VXI',
#   'Year': 2017,
#   'Selling_Price': 365000,
#   'Kms_Driven': 78000,
#   'Fuel_Type': 'CNG',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Chevrolet Sail 1.2 Base',
#   'Year': 2015,
#   'Selling_Price': 260000,
#   'Kms_Driven': 35000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Tata Indigo Grand Petrol',
#   'Year': 2014,
#   'Selling_Price': 250000,
#   'Kms_Driven': 100000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Toyota Corolla Altis 1.8 VL CVT',
#   'Year': 2018,
#   'Selling_Price': 1650000,
#   'Kms_Driven': 25000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Ciaz VXi Plus',
#   'Year': 2015,
#   'Selling_Price': 585000,
#   'Kms_Driven': 24000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Venue SX Opt Diesel',
#   'Year': 2019,
#   'Selling_Price': 1195000,
#   'Kms_Driven': 5000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Chevrolet Enjoy TCDi LTZ 7 Seater',
#   'Year': 2013,
#   'Selling_Price': 390000,
#   'Kms_Driven': 33000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Jaguar XF 2.2 Litre Luxury',
#   'Year': 2014,
#   'Selling_Price': 1964999,
#   'Kms_Driven': 28000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mercedes-Benz New C-Class 220 CDI AT',
#   'Year': 2013,
#   'Selling_Price': 1425000,
#   'Kms_Driven': 59000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Vitara Brezza ZDi Plus AMT',
#   'Year': 2018,
#   'Selling_Price': 975000,
#   'Kms_Driven': 4500,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Audi Q5 2.0 TDI',
#   'Year': 2011,
#   'Selling_Price': 1190000,
#   'Kms_Driven': 175900,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Honda City V MT',
#   'Year': 2018,
#   'Selling_Price': 930000,
#   'Kms_Driven': 14500,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Tata Tigor 1.2 Revotron XT',
#   'Year': 2018,
#   'Selling_Price': 525000,
#   'Kms_Driven': 15000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Audi A6 2.0 TDI  Design Edition',
#   'Year': 2013,
#   'Selling_Price': 1735000,
#   'Kms_Driven': 50000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mercedes-Benz New C-Class C 220 CDI Avantgarde',
#   'Year': 2012,
#   'Selling_Price': 1375000,
#   'Kms_Driven': 33800,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Skoda Superb Ambition 2.0 TDI CR AT',
#   'Year': 2011,
#   'Selling_Price': 450000,
#   'Kms_Driven': 130400,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Toyota Corolla Altis G AT',
#   'Year': 2016,
#   'Selling_Price': 900000,
#   'Kms_Driven': 50000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Toyota Innova 2.5 G (Diesel) 7 Seater',
#   'Year': 2015,
#   'Selling_Price': 1300000,
#   'Kms_Driven': 80000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Jeep Compass 1.4 Sport Plus BSIV',
#   'Year': 2019,
#   'Selling_Price': 1400000,
#   'Kms_Driven': 10000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mercedes-Benz E-Class E 200 CGI Elegance',
#   'Year': 2010,
#   'Selling_Price': 850000,
#   'Kms_Driven': 119000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai i10 Magna 1.1L',
#   'Year': 2014,
#   'Selling_Price': 229999,
#   'Kms_Driven': 60000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Fourth & Above Owner'},
#  {'Car_Name': 'BMW 3 Series 320d Sport Line',
#   'Year': 2013,
#   'Selling_Price': 1550000,
#   'Kms_Driven': 75800,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Audi Q7 35 TDI Quattro Premium',
#   'Year': 2009,
#   'Selling_Price': 1250000,
#   'Kms_Driven': 78000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'Third Owner'},
#  {'Car_Name': 'Hyundai Elantra CRDi S',
#   'Year': 2012,
#   'Selling_Price': 625000,
#   'Kms_Driven': 40000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mahindra Scorpio 1.99 S10',
#   'Year': 2014,
#   'Selling_Price': 1050000,
#   'Kms_Driven': 50000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Honda City i DTEC V',
#   'Year': 2014,
#   'Selling_Price': 560000,
#   'Kms_Driven': 74000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Maruti Wagon R VXI BS IV with ABS',
#   'Year': 2014,
#   'Selling_Price': 290000,
#   'Kms_Driven': 64000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Maruti Wagon R VXI BS IV',
#   'Year': 2012,
#   'Selling_Price': 275000,
#   'Kms_Driven': 60000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Mahindra Scorpio LX',
#   'Year': 2009,
#   'Selling_Price': 411000,
#   'Kms_Driven': 120000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Hyundai Santro Xing GLS',
#   'Year': 2009,
#   'Selling_Price': 150000,
#   'Kms_Driven': 79000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Third Owner'},
#  {'Car_Name': 'Hyundai Grand i10 1.2 Kappa Asta',
#   'Year': 2019,
#   'Selling_Price': 500000,
#   'Kms_Driven': 15000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Alto LXi',
#   'Year': 2006,
#   'Selling_Price': 100000,
#   'Kms_Driven': 80000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Swift Dzire VDI Optional',
#   'Year': 2017,
#   'Selling_Price': 725000,
#   'Kms_Driven': 18500,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Eeco 5 Seater AC BSIV',
#   'Year': 2018,
#   'Selling_Price': 401000,
#   'Kms_Driven': 10200,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai i20 Sportz 1.4 CRDi',
#   'Year': 2018,
#   'Selling_Price': 750000,
#   'Kms_Driven': 29000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Omni Maruti Omni MPI STD BSIII 5-STR W/ IMMOBILISER',
#   'Year': 2018,
#   'Selling_Price': 310000,
#   'Kms_Driven': 28000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Swift ZDi BSIV',
#   'Year': 2016,
#   'Selling_Price': 665000,
#   'Kms_Driven': 46000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai i20 2015-2017 Sportz Option 1.4 CRDi',
#   'Year': 2014,
#   'Selling_Price': 465000,
#   'Kms_Driven': 70000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Alto LXi',
#   'Year': 2012,
#   'Selling_Price': 160000,
#   'Kms_Driven': 60000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Mahindra Jeep CL 500 MDI',
#   'Year': 1996,
#   'Selling_Price': 250000,
#   'Kms_Driven': 35000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Honda City i DTEC VX',
#   'Year': 2014,
#   'Selling_Price': 675000,
#   'Kms_Driven': 90000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Wagon R VXI BS IV',
#   'Year': 2013,
#   'Selling_Price': 300000,
#   'Kms_Driven': 80000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Tata Indica DLS',
#   'Year': 2005,
#   'Selling_Price': 70000,
#   'Kms_Driven': 80000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai EON Magna Plus',
#   'Year': 2014,
#   'Selling_Price': 240000,
#   'Kms_Driven': 73300,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Toyota Etios GD',
#   'Year': 2014,
#   'Selling_Price': 525000,
#   'Kms_Driven': 92000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Alto LXi',
#   'Year': 2009,
#   'Selling_Price': 151000,
#   'Kms_Driven': 66764,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Maruti Alto LXi',
#   'Year': 2009,
#   'Selling_Price': 140000,
#   'Kms_Driven': 100000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Chevrolet Tavera Neo LS B3 - 7(C) seats BSIII',
#   'Year': 2010,
#   'Selling_Price': 280000,
#   'Kms_Driven': 350000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Toyota Corolla Altis Diesel D4DG',
#   'Year': 2011,
#   'Selling_Price': 350000,
#   'Kms_Driven': 230000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mahindra Scorpio 1.99 S6 Plus',
#   'Year': 2017,
#   'Selling_Price': 570000,
#   'Kms_Driven': 60000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai EON Magna Plus',
#   'Year': 2018,
#   'Selling_Price': 300000,
#   'Kms_Driven': 31000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Tata Indigo Classic Dicor',
#   'Year': 2007,
#   'Selling_Price': 100000,
#   'Kms_Driven': 39000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Toyota Innova 2.5 V Diesel 8-seater',
#   'Year': 2009,
#   'Selling_Price': 500000,
#   'Kms_Driven': 120000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Third Owner'},
#  {'Car_Name': 'Tata Indica Vista Quadrajet LS',
#   'Year': 2014,
#   'Selling_Price': 125000,
#   'Kms_Driven': 166000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Fourth & Above Owner'},
#  {'Car_Name': 'Maruti Swift 1.3 VXi',
#   'Year': 2006,
#   'Selling_Price': 130000,
#   'Kms_Driven': 110000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Third Owner'},
#  {'Car_Name': 'Ford EcoSport 1.5 Diesel Titanium BSIV',
#   'Year': 2017,
#   'Selling_Price': 925000,
#   'Kms_Driven': 35000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Ciaz 1.3 Delta',
#   'Year': 2018,
#   'Selling_Price': 750000,
#   'Kms_Driven': 60000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Honda Civic 1.8 V AT',
#   'Year': 2007,
#   'Selling_Price': 200000,
#   'Kms_Driven': 54000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Automatic',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Hyundai i10 Sportz 1.2',
#   'Year': 2010,
#   'Selling_Price': 248000,
#   'Kms_Driven': 63000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Skoda Rapid 1.5 TDI Elegance',
#   'Year': 2014,
#   'Selling_Price': 450000,
#   'Kms_Driven': 120000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Hyundai Getz GLS',
#   'Year': 2005,
#   'Selling_Price': 80000,
#   'Kms_Driven': 120000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Third Owner'},
#  {'Car_Name': 'Nissan Terrano XL',
#   'Year': 2014,
#   'Selling_Price': 650000,
#   'Kms_Driven': 76000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Hyundai Grand i10 CRDi Sportz',
#   'Year': 2015,
#   'Selling_Price': 450000,
#   'Kms_Driven': 80000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Elite i20 Diesel Era',
#   'Year': 2019,
#   'Selling_Price': 650000,
#   'Kms_Driven': 25000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Honda Amaze S i-VTEC',
#   'Year': 2016,
#   'Selling_Price': 495000,
#   'Kms_Driven': 11958,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Honda Brio S MT',
#   'Year': 2015,
#   'Selling_Price': 371000,
#   'Kms_Driven': 20000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Creta 1.6 SX Option',
#   'Year': 2017,
#   'Selling_Price': 1025000,
#   'Kms_Driven': 9000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mercedes-Benz S-Class S 350d Connoisseurs Edition',
#   'Year': 2017,
#   'Selling_Price': 8150000,
#   'Kms_Driven': 6500,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mahindra XUV500 W8 2WD',
#   'Year': 2015,
#   'Selling_Price': 750000,
#   'Kms_Driven': 70000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Renault Duster 85PS Diesel RxL Optional',
#   'Year': 2013,
#   'Selling_Price': 600000,
#   'Kms_Driven': 120000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Santro Xing XO',
#   'Year': 2007,
#   'Selling_Price': 80000,
#   'Kms_Driven': 58000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Mahindra Bolero 2011-2019 SLE',
#   'Year': 2013,
#   'Selling_Price': 325000,
#   'Kms_Driven': 62200,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Audi A6 2.0 TDI Premium Plus',
#   'Year': 2014,
#   'Selling_Price': 1470000,
#   'Kms_Driven': 34000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Fiat Avventura MULTIJET Emotion',
#   'Year': 2015,
#   'Selling_Price': 350000,
#   'Kms_Driven': 53000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Audi A8 4.2 TDI',
#   'Year': 2013,
#   'Selling_Price': 2800000,
#   'Kms_Driven': 49000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Datsun RediGO 1.0 S',
#   'Year': 2017,
#   'Selling_Price': 210000,
#   'Kms_Driven': 15000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Volkswagen Jetta 1.4 TSI Comfortline',
#   'Year': 2013,
#   'Selling_Price': 450000,
#   'Kms_Driven': 50000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Audi A4 2.0 TDI 177 Bhp Premium Plus',
#   'Year': 2013,
#   'Selling_Price': 1150000,
#   'Kms_Driven': 53000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Honda Civic 1.8 V AT',
#   'Year': 2009,
#   'Selling_Price': 210000,
#   'Kms_Driven': 63500,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mercedes-Benz E-Class Exclusive E 200 BSIV',
#   'Year': 2018,
#   'Selling_Price': 4500000,
#   'Kms_Driven': 9800,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'BMW X1 sDrive 20d xLine',
#   'Year': 2017,
#   'Selling_Price': 2750000,
#   'Kms_Driven': 13000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Volvo V40 D3 R Design',
#   'Year': 2018,
#   'Selling_Price': 1975000,
#   'Kms_Driven': 21000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti SX4 Zxi BSIII',
#   'Year': 2008,
#   'Selling_Price': 175000,
#   'Kms_Driven': 29173,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'BMW 7 Series 730Ld',
#   'Year': 2012,
#   'Selling_Price': 2500000,
#   'Kms_Driven': 48000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mahindra Bolero Power Plus SLX',
#   'Year': 2017,
#   'Selling_Price': 628000,
#   'Kms_Driven': 120000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Sonata CRDi M/T',
#   'Year': 2010,
#   'Selling_Price': 600000,
#   'Kms_Driven': 100000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Nissan Micra Active XV Petrol',
#   'Year': 2017,
#   'Selling_Price': 399000,
#   'Kms_Driven': 30000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mahindra Xylo D4',
#   'Year': 2018,
#   'Selling_Price': 750000,
#   'Kms_Driven': 87000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Elite i20 Sportz Plus Dual Tone BSIV',
#   'Year': 2019,
#   'Selling_Price': 750000,
#   'Kms_Driven': 15000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Renault KWID RXT',
#   'Year': 2017,
#   'Selling_Price': 315000,
#   'Kms_Driven': 16000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mahindra Xylo E4 BS III',
#   'Year': 2012,
#   'Selling_Price': 600000,
#   'Kms_Driven': 60000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Wagon R LXI Minor',
#   'Year': 2010,
#   'Selling_Price': 100000,
#   'Kms_Driven': 60000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Fourth & Above Owner'},
#  {'Car_Name': 'Maruti SX4 ZXI MT BSIV',
#   'Year': 2011,
#   'Selling_Price': 250000,
#   'Kms_Driven': 110000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Third Owner'},
#  {'Car_Name': 'Renault KWID RXT',
#   'Year': 2017,
#   'Selling_Price': 350000,
#   'Kms_Driven': 25000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Creta 1.4 CRDi S',
#   'Year': 2016,
#   'Selling_Price': 780000,
#   'Kms_Driven': 60000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Swift Dzire VDI',
#   'Year': 2014,
#   'Selling_Price': 434000,
#   'Kms_Driven': 79350,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Hyundai Verna 1.6 VTVT AT S Option',
#   'Year': 2016,
#   'Selling_Price': 690000,
#   'Kms_Driven': 80000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mahindra Scorpio LX BSIV',
#   'Year': 2014,
#   'Selling_Price': 555000,
#   'Kms_Driven': 90000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Maruti SX4 Vxi BSIII',
#   'Year': 2007,
#   'Selling_Price': 120000,
#   'Kms_Driven': 90000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Maruti Ertiga VDI',
#   'Year': 2014,
#   'Selling_Price': 500000,
#   'Kms_Driven': 120000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Chevrolet Beat Diesel',
#   'Year': 2013,
#   'Selling_Price': 165000,
#   'Kms_Driven': 60000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Maruti Zen LX',
#   'Year': 2004,
#   'Selling_Price': 95000,
#   'Kms_Driven': 50000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Baleno Delta 1.2',
#   'Year': 2018,
#   'Selling_Price': 550000,
#   'Kms_Driven': 20000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Swift Vdi BSIII',
#   'Year': 2007,
#   'Selling_Price': 100000,
#   'Kms_Driven': 110000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Fourth & Above Owner'},
#  {'Car_Name': 'Tata Nano Lx BSIV',
#   'Year': 2012,
#   'Selling_Price': 100000,
#   'Kms_Driven': 50000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Toyota Innova 2.5 GX (Diesel) 8 Seater',
#   'Year': 2012,
#   'Selling_Price': 500000,
#   'Kms_Driven': 100000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Ertiga SHVS VDI',
#   'Year': 2016,
#   'Selling_Price': 800000,
#   'Kms_Driven': 70000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Hyundai Creta 1.6 CRDi SX',
#   'Year': 2016,
#   'Selling_Price': 840000,
#   'Kms_Driven': 70000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Honda Amaze S i-Vtech',
#   'Year': 2016,
#   'Selling_Price': 490000,
#   'Kms_Driven': 50000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Tata Indica Vista Aqua 1.4 TDI',
#   'Year': 2010,
#   'Selling_Price': 125000,
#   'Kms_Driven': 81000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Chevrolet Tavera Neo 2 LS B4 7 Str BSIII',
#   'Year': 2012,
#   'Selling_Price': 400000,
#   'Kms_Driven': 120000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Third Owner'},
#  {'Car_Name': 'Chevrolet Cruze LTZ',
#   'Year': 2015,
#   'Selling_Price': 1000000,
#   'Kms_Driven': 3600,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Ford Figo Aspire 1.2 Ti-VCT Titanium Plus',
#   'Year': 2015,
#   'Selling_Price': 530000,
#   'Kms_Driven': 14272,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Ford EcoSport 1.5 Diesel Titanium Plus BSIV',
#   'Year': 2017,
#   'Selling_Price': 840000,
#   'Kms_Driven': 49213,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai i10 Sportz 1.1L',
#   'Year': 2015,
#   'Selling_Price': 229999,
#   'Kms_Driven': 40000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti 800 Std',
#   'Year': 1998,
#   'Selling_Price': 40000,
#   'Kms_Driven': 40000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Fourth & Above Owner'},
#  {'Car_Name': 'Chevrolet Spark 1.0 LS',
#   'Year': 2012,
#   'Selling_Price': 130000,
#   'Kms_Driven': 80000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai EON Era Plus',
#   'Year': 2015,
#   'Selling_Price': 200000,
#   'Kms_Driven': 70000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Tata Indica Vista Aqua TDI BSIII',
#   'Year': 2011,
#   'Selling_Price': 120000,
#   'Kms_Driven': 70000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Santro LP zipPlus',
#   'Year': 2003,
#   'Selling_Price': 75000,
#   'Kms_Driven': 57000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Tata Bolt Quadrajet XE',
#   'Year': 2016,
#   'Selling_Price': 250000,
#   'Kms_Driven': 120000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti 800 AC BSIII',
#   'Year': 2005,
#   'Selling_Price': 100000,
#   'Kms_Driven': 30000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai EON Era Plus',
#   'Year': 2013,
#   'Selling_Price': 280000,
#   'Kms_Driven': 3240,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Hyundai i20 Magna 1.2',
#   'Year': 2015,
#   'Selling_Price': 540000,
#   'Kms_Driven': 5000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai i20 1.2 Asta',
#   'Year': 2018,
#   'Selling_Price': 700000,
#   'Kms_Driven': 10000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Ciaz VDi Plus',
#   'Year': 2015,
#   'Selling_Price': 525000,
#   'Kms_Driven': 100000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai i20 Asta 1.4 CRDi',
#   'Year': 2016,
#   'Selling_Price': 430000,
#   'Kms_Driven': 80000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Santro LE',
#   'Year': 2002,
#   'Selling_Price': 65000,
#   'Kms_Driven': 70000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Vitara Brezza VDi',
#   'Year': 2018,
#   'Selling_Price': 800000,
#   'Kms_Driven': 35000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Santro Xing XL eRLX Euro III',
#   'Year': 2007,
#   'Selling_Price': 75000,
#   'Kms_Driven': 114000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Hyundai Getz 1.3 GLS',
#   'Year': 2008,
#   'Selling_Price': 210000,
#   'Kms_Driven': 53772,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mahindra Quanto C8',
#   'Year': 2012,
#   'Selling_Price': 195000,
#   'Kms_Driven': 140000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Chevrolet Tavera Neo 3 LS 7 C BSIII',
#   'Year': 2015,
#   'Selling_Price': 400000,
#   'Kms_Driven': 120000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai EON Magna Plus',
#   'Year': 2012,
#   'Selling_Price': 170000,
#   'Kms_Driven': 60000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Renault KWID RXT',
#   'Year': 2016,
#   'Selling_Price': 225000,
#   'Kms_Driven': 25000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Wagon R DUO LPG',
#   'Year': 2014,
#   'Selling_Price': 210000,
#   'Kms_Driven': 90000,
#   'Fuel_Type': 'LPG',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Wagon R LXI',
#   'Year': 2020,
#   'Selling_Price': 240000,
#   'Kms_Driven': 120000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Chevrolet Enjoy 1.3 TCDi LS 8',
#   'Year': 2015,
#   'Selling_Price': 300000,
#   'Kms_Driven': 175000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Chevrolet Spark 1.0 LS',
#   'Year': 2011,
#   'Selling_Price': 99000,
#   'Kms_Driven': 100000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Third Owner'},
#  {'Car_Name': 'Honda City i VTEC SV',
#   'Year': 2014,
#   'Selling_Price': 620000,
#   'Kms_Driven': 36000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Honda Amaze VX i-DTEC',
#   'Year': 2013,
#   'Selling_Price': 500000,
#   'Kms_Driven': 30000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Jaguar XJ 5.0 L V8 Supercharged',
#   'Year': 2010,
#   'Selling_Price': 2550000,
#   'Kms_Driven': 40000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Automatic',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Honda Brio E MT',
#   'Year': 2013,
#   'Selling_Price': 260000,
#   'Kms_Driven': 70000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Maruti Swift VVT ZXI',
#   'Year': 2017,
#   'Selling_Price': 550000,
#   'Kms_Driven': 60000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Tata Indigo CR4',
#   'Year': 2011,
#   'Selling_Price': 150000,
#   'Kms_Driven': 155500,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai i10 Asta AT',
#   'Year': 2011,
#   'Selling_Price': 350000,
#   'Kms_Driven': 50000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Automatic',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Chevrolet Beat LT',
#   'Year': 2016,
#   'Selling_Price': 320000,
#   'Kms_Driven': 40000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Swift VDI BSIV',
#   'Year': 2015,
#   'Selling_Price': 400000,
#   'Kms_Driven': 100000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Third Owner'},
#  {'Car_Name': 'Maruti Alto LXi',
#   'Year': 2012,
#   'Selling_Price': 175000,
#   'Kms_Driven': 80000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Third Owner'},
#  {'Car_Name': 'Chevrolet Beat LT',
#   'Year': 2011,
#   'Selling_Price': 120000,
#   'Kms_Driven': 90000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Renault Duster 110PS Diesel RxZ',
#   'Year': 2013,
#   'Selling_Price': 320000,
#   'Kms_Driven': 90000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Hyundai Santro Xing XG',
#   'Year': 2006,
#   'Selling_Price': 70000,
#   'Kms_Driven': 110000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Third Owner'},
#  {'Car_Name': 'Maruti Swift Dzire ZXI Plus',
#   'Year': 2019,
#   'Selling_Price': 810000,
#   'Kms_Driven': 15000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti 800 AC',
#   'Year': 2007,
#   'Selling_Price': 95000,
#   'Kms_Driven': 100000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Maruti Alto K10 LXI CNG',
#   'Year': 2020,
#   'Selling_Price': 282000,
#   'Kms_Driven': 40000,
#   'Fuel_Type': 'CNG',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti 800 Std BSII',
#   'Year': 2004,
#   'Selling_Price': 80000,
#   'Kms_Driven': 60000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Tata Nano LX SE',
#   'Year': 2013,
#   'Selling_Price': 72000,
#   'Kms_Driven': 25000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai i20 Magna 1.2',
#   'Year': 2016,
#   'Selling_Price': 600000,
#   'Kms_Driven': 25000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Skoda Rapid 1.6 MPI Ambition With Alloy Wheel',
#   'Year': 2015,
#   'Selling_Price': 640000,
#   'Kms_Driven': 23000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Alto K10 VXI',
#   'Year': 2018,
#   'Selling_Price': 380000,
#   'Kms_Driven': 22155,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Ciaz 1.4 Delta',
#   'Year': 2018,
#   'Selling_Price': 650000,
#   'Kms_Driven': 70000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Alto LX',
#   'Year': 2009,
#   'Selling_Price': 150000,
#   'Kms_Driven': 60000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Hyundai i20 Asta',
#   'Year': 2009,
#   'Selling_Price': 280000,
#   'Kms_Driven': 110000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Tata Nexon 1.2 Revotron XM',
#   'Year': 2018,
#   'Selling_Price': 430000,
#   'Kms_Driven': 30000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mahindra Bolero Power Plus SLX',
#   'Year': 2019,
#   'Selling_Price': 800000,
#   'Kms_Driven': 15000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Zen D',
#   'Year': 2003,
#   'Selling_Price': 75000,
#   'Kms_Driven': 100000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Volkswagen Vento Celeste 1.5 TDI Highline AT',
#   'Year': 2016,
#   'Selling_Price': 650000,
#   'Kms_Driven': 70000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Eeco 7 Seater Standard BSIV',
#   'Year': 2017,
#   'Selling_Price': 390000,
#   'Kms_Driven': 24000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Honda City 1.5 EXI',
#   'Year': 2005,
#   'Selling_Price': 100000,
#   'Kms_Driven': 120000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Mercedes-Benz New C-Class 220 CDI AT',
#   'Year': 2013,
#   'Selling_Price': 1500000,
#   'Kms_Driven': 35000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti SX4 Zxi with Leather BSIII',
#   'Year': 2007,
#   'Selling_Price': 175000,
#   'Kms_Driven': 78380,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Renault Duster 110PS Diesel RxZ',
#   'Year': 2012,
#   'Selling_Price': 434999,
#   'Kms_Driven': 110000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Ford Figo Diesel Titanium',
#   'Year': 2010,
#   'Selling_Price': 170000,
#   'Kms_Driven': 90000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Third Owner'},
#  {'Car_Name': 'Ford Figo Diesel Titanium',
#   'Year': 2011,
#   'Selling_Price': 190000,
#   'Kms_Driven': 90000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Third Owner'},
#  {'Car_Name': 'Maruti Swift Dzire VDi',
#   'Year': 2009,
#   'Selling_Price': 250000,
#   'Kms_Driven': 150000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Third Owner'},
#  {'Car_Name': 'Mahindra Xylo E4',
#   'Year': 2009,
#   'Selling_Price': 229999,
#   'Kms_Driven': 230000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Third Owner'},
#  {'Car_Name': 'Maruti Esteem Vxi - BSIII',
#   'Year': 2006,
#   'Selling_Price': 140000,
#   'Kms_Driven': 70000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Third Owner'},
#  {'Car_Name': 'Maruti Swift VDI BSIV',
#   'Year': 2017,
#   'Selling_Price': 600000,
#   'Kms_Driven': 80362,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai i20 1.2 Sportz',
#   'Year': 2012,
#   'Selling_Price': 280000,
#   'Kms_Driven': 110000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Third Owner'},
#  {'Car_Name': 'Chevrolet Beat Diesel LT',
#   'Year': 2012,
#   'Selling_Price': 150000,
#   'Kms_Driven': 60000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Chevrolet Cruze LTZ AT',
#   'Year': 2015,
#   'Selling_Price': 650000,
#   'Kms_Driven': 50000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Nissan Micra XL',
#   'Year': 2014,
#   'Selling_Price': 210000,
#   'Kms_Driven': 40000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'BMW 5 Series 520d Luxury Line',
#   'Year': 2017,
#   'Selling_Price': 2900000,
#   'Kms_Driven': 40000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Chevrolet Enjoy 1.3 TCDi LS 8',
#   'Year': 2013,
#   'Selling_Price': 425000,
#   'Kms_Driven': 20000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai EON Era Plus Option',
#   'Year': 2014,
#   'Selling_Price': 265000,
#   'Kms_Driven': 55000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Fiat Linea T Jet Emotion',
#   'Year': 2018,
#   'Selling_Price': 890000,
#   'Kms_Driven': 1136,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Renault Scala RxL',
#   'Year': 2013,
#   'Selling_Price': 365000,
#   'Kms_Driven': 55000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Ford Figo Petrol Titanium',
#   'Year': 2014,
#   'Selling_Price': 350000,
#   'Kms_Driven': 43000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Ciaz ZDi SHVS',
#   'Year': 2016,
#   'Selling_Price': 685000,
#   'Kms_Driven': 60000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Skoda Rapid 1.5 TDI Ambition BSIV',
#   'Year': 2018,
#   'Selling_Price': 940000,
#   'Kms_Driven': 2650,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mahindra XUV500 W6 2WD',
#   'Year': 2017,
#   'Selling_Price': 1000000,
#   'Kms_Driven': 40000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mahindra XUV300 W8 Option',
#   'Year': 2019,
#   'Selling_Price': 1150000,
#   'Kms_Driven': 15000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Ertiga SHVS ZDI',
#   'Year': 2016,
#   'Selling_Price': 450000,
#   'Kms_Driven': 115962,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Nissan Terrano XE D',
#   'Year': 2015,
#   'Selling_Price': 590000,
#   'Kms_Driven': 65000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti S-Cross Facelift',
#   'Year': 2017,
#   'Selling_Price': 800000,
#   'Kms_Driven': 40000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai i20 Magna 1.4 CRDi (Diesel)',
#   'Year': 2012,
#   'Selling_Price': 385000,
#   'Kms_Driven': 58000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mercedes-Benz New C-Class C 220 CDI BE Avantgare',
#   'Year': 2013,
# ...
#   'Seller_Type': 'Trustmark Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti S-Cross Zeta DDiS 200 SH',
#   'Year': 2015,
#   'Selling_Price': 750000,
#   'Kms_Driven': 45974,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Trustmark Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai i10 Magna',
#   'Year': 2012,
#   'Selling_Price': 229999,
#   'Kms_Driven': 49824,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Audi A6 2.0 TDI Premium Plus',
#   'Year': 2013,
#   'Selling_Price': 1300000,
#   'Kms_Driven': 58500,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Santro GS',
#   'Year': 2005,
#   'Selling_Price': 80000,
#   'Kms_Driven': 56580,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Skoda Laura Ambiente 2.0 TDI CR MT',
#   'Year': 2012,
#   'Selling_Price': 385000,
#   'Kms_Driven': 52000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Verna 1.6 VTVT SX',
#   'Year': 2015,
#   'Selling_Price': 760000,
#   'Kms_Driven': 55340,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Trustmark Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Swift Dzire VDI',
#   'Year': 2017,
#   'Selling_Price': 600000,
#   'Kms_Driven': 46507,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Trustmark Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Volkswagen Jetta 2.0L TDI Highline AT',
#   'Year': 2012,
#   'Selling_Price': 735000,
#   'Kms_Driven': 55300,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Tata Indica Vista Quadrajet 90 VX',
#   'Year': 2012,
#   'Selling_Price': 285000,
#   'Kms_Driven': 74300,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Honda City VX MT',
#   'Year': 2010,
#   'Selling_Price': 350000,
#   'Kms_Driven': 48781,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Volkswagen Jetta 1.9 Highline TDI',
#   'Year': 2010,
#   'Selling_Price': 290000,
#   'Kms_Driven': 87620,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Volkswagen Vento 1.5 TDI Highline Plus AT',
#   'Year': 2017,
#   'Selling_Price': 890000,
#   'Kms_Driven': 40219,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Honda Jazz VX',
#   'Year': 2011,
#   'Selling_Price': 385000,
#   'Kms_Driven': 11473,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Eeco 5 Seater AC BSIV',
#   'Year': 2017,
#   'Selling_Price': 425000,
#   'Kms_Driven': 8352,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Wagon R VXI AMT1.2BSIV',
#   'Year': 2017,
#   'Selling_Price': 525000,
#   'Kms_Driven': 9745,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Grand i10 Asta',
#   'Year': 2017,
#   'Selling_Price': 550000,
#   'Kms_Driven': 9748,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Volkswagen Polo 1.0 MPI Trendline',
#   'Year': 2012,
#   'Selling_Price': 271000,
#   'Kms_Driven': 49000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Creta 1.6 CRDi SX Option',
#   'Year': 2018,
#   'Selling_Price': 1490000,
#   'Kms_Driven': 20694,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Grand i10 Asta Option',
#   'Year': 2015,
#   'Selling_Price': 490000,
#   'Kms_Driven': 31080,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai EON Era Plus',
#   'Year': 2014,
#   'Selling_Price': 260000,
#   'Kms_Driven': 37605,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Xcent 1.1 CRDi SX Option',
#   'Year': 2014,
#   'Selling_Price': 455000,
#   'Kms_Driven': 55850,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Tata Nano Lx BSIV',
#   'Year': 2010,
#   'Selling_Price': 75000,
#   'Kms_Driven': 58850,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Toyota Etios Cross 1.2L G',
#   'Year': 2015,
#   'Selling_Price': 421000,
#   'Kms_Driven': 23839,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Swift DDiS LDI',
#   'Year': 2016,
#   'Selling_Price': 550000,
#   'Kms_Driven': 54000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai i10 Sportz 1.2 AT',
#   'Year': 2013,
#   'Selling_Price': 330000,
#   'Kms_Driven': 38000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Volkswagen Vento 1.5 TDI Comfortline',
#   'Year': 2012,
#   'Selling_Price': 390000,
#   'Kms_Driven': 45454,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Skoda Rapid 1.5 TDI AT Ambition',
#   'Year': 2015,
#   'Selling_Price': 599000,
#   'Kms_Driven': 46957,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Dealer',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Getz GLE',
#   'Year': 2007,
#   'Selling_Price': 110000,
#   'Kms_Driven': 60000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Fourth & Above Owner'},
#  {'Car_Name': 'Renault KWID RXT Optional',
#   'Year': 2016,
#   'Selling_Price': 250000,
#   'Kms_Driven': 25000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mahindra Scorpio M2DI',
#   'Year': 2012,
#   'Selling_Price': 600000,
#   'Kms_Driven': 110000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Fourth & Above Owner'},
#  {'Car_Name': 'Ford Endeavour XLT TDCi 4X2',
#   'Year': 2008,
#   'Selling_Price': 280000,
#   'Kms_Driven': 190000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Audi Q3 35 TDI Quattro Technology',
#   'Year': 2018,
#   'Selling_Price': 2700000,
#   'Kms_Driven': 25000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mahindra Renault Logan 1.4 GLX Petrol',
#   'Year': 2008,
#   'Selling_Price': 80000,
#   'Kms_Driven': 90000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Alto K10 VXI',
#   'Year': 2019,
#   'Selling_Price': 350000,
#   'Kms_Driven': 5000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Swift VDI BSIV',
#   'Year': 2015,
#   'Selling_Price': 475000,
#   'Kms_Driven': 60000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Audi A5 Sportback',
#   'Year': 2020,
#   'Selling_Price': 4700000,
#   'Kms_Driven': 1500,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Swift Dzire VDI',
#   'Year': 2018,
#   'Selling_Price': 500000,
#   'Kms_Driven': 50000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Chevrolet Sail Hatchback 1.3 TCDi LT ABS',
#   'Year': 2014,
#   'Selling_Price': 250000,
#   'Kms_Driven': 120000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Accent CRDi',
#   'Year': 2005,
#   'Selling_Price': 100000,
#   'Kms_Driven': 120000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Maruti Alto K10 VXI Airbag',
#   'Year': 2019,
#   'Selling_Price': 350000,
#   'Kms_Driven': 5000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'BMW 7 Series Signature 730Ld',
#   'Year': 2014,
#   'Selling_Price': 4000000,
#   'Kms_Driven': 47000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Toyota Camry 2.5 Hybrid',
#   'Year': 2017,
#   'Selling_Price': 1900000,
#   'Kms_Driven': 20000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Santro Xing XG',
#   'Year': 2005,
#   'Selling_Price': 95000,
#   'Kms_Driven': 120000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Hyundai Grand i10 CRDi Sportz',
#   'Year': 2015,
#   'Selling_Price': 409999,
#   'Kms_Driven': 58000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mahindra XUV500 W5 BSIV',
#   'Year': 2018,
#   'Selling_Price': 1050000,
#   'Kms_Driven': 35000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Alto K10 VXI',
#   'Year': 2017,
#   'Selling_Price': 320000,
#   'Kms_Driven': 30000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mahindra XUV300 W8 Option Diesel BSIV',
#   'Year': 2019,
#   'Selling_Price': 1000000,
#   'Kms_Driven': 10000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Toyota Innova Crysta 2.4 VX MT BSIV',
#   'Year': 2017,
#   'Selling_Price': 1770000,
#   'Kms_Driven': 25000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mahindra Thar CRDe',
#   'Year': 2018,
#   'Selling_Price': 950000,
#   'Kms_Driven': 20000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Swift Dzire ZDI',
#   'Year': 2018,
#   'Selling_Price': 750000,
#   'Kms_Driven': 50000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai EON Magna Plus',
#   'Year': 2014,
#   'Selling_Price': 220000,
#   'Kms_Driven': 42000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Tata Hexa XM',
#   'Year': 2017,
#   'Selling_Price': 1000000,
#   'Kms_Driven': 50000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Honda Mobilio E i DTEC',
#   'Year': 2017,
#   'Selling_Price': 660000,
#   'Kms_Driven': 116000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Ertiga ZDI',
#   'Year': 2015,
#   'Selling_Price': 716000,
#   'Kms_Driven': 100000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Ciaz ZXi Plus',
#   'Year': 2015,
#   'Selling_Price': 675000,
#   'Kms_Driven': 66000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mahindra Scorpio LX',
#   'Year': 2010,
#   'Selling_Price': 385000,
#   'Kms_Driven': 110000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Third Owner'},
#  {'Car_Name': 'Fiat Grande Punto EVO 1.3 Dynamic',
#   'Year': 2014,
#   'Selling_Price': 325000,
#   'Kms_Driven': 70000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Creta 1.6 CRDi SX Option',
#   'Year': 2015,
#   'Selling_Price': 950000,
#   'Kms_Driven': 60000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Ford Endeavour Hurricane Limited Edition',
#   'Year': 2007,
#   'Selling_Price': 400000,
#   'Kms_Driven': 110000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Automatic',
#   'Owner': 'Fourth & Above Owner'},
#  {'Car_Name': 'Tata Indica Vista TDI LS',
#   'Year': 2014,
#   'Selling_Price': 250000,
#   'Kms_Driven': 25000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Land Rover Discovery S 2.0 SD4',
#   'Year': 2018,
#   'Selling_Price': 4000000,
#   'Kms_Driven': 68000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Automatic',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Maruti Alto 800 LXI',
#   'Year': 2014,
#   'Selling_Price': 210000,
#   'Kms_Driven': 20000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai i10 Era 1.1 iTech SE',
#   'Year': 2011,
#   'Selling_Price': 147000,
#   'Kms_Driven': 110000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Maruti Vitara Brezza VDi Option',
#   'Year': 2018,
#   'Selling_Price': 725000,
#   'Kms_Driven': 26350,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Mahindra Scorpio SLE BSIV',
#   'Year': 2012,
#   'Selling_Price': 550000,
#   'Kms_Driven': 90000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai i20 Sportz Option 1.2',
#   'Year': 2016,
#   'Selling_Price': 475000,
#   'Kms_Driven': 25000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Santro Xing GLS',
#   'Year': 2014,
#   'Selling_Price': 250000,
#   'Kms_Driven': 50000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Tata Indica LSI',
#   'Year': 2006,
#   'Selling_Price': 70000,
#   'Kms_Driven': 60000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Hyundai EON Era Plus',
#   'Year': 2012,
#   'Selling_Price': 160000,
#   'Kms_Driven': 70000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'Third Owner'},
#  {'Car_Name': 'Ford Endeavour 3.0L 4X4 AT',
#   'Year': 2011,
#   'Selling_Price': 1000000,
#   'Kms_Driven': 90000,
#   'Fuel_Type': 'Diesel',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Automatic',
#   'Owner': 'Second Owner'},
#  {'Car_Name': 'Hyundai Santro LE zipPlus',
#   'Year': 2001,
#   'Selling_Price': 68000,
#   'Kms_Driven': 70000,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  {'Car_Name': 'Hyundai Grand i10 1.2 Kappa Asta',
#   'Year': 2017,
#   'Selling_Price': 500000,
#   'Kms_Driven': 26500,
#   'Fuel_Type': 'Petrol',
#   'Seller_Type': 'Individual',
#   'Transmission': 'Manual',
#   'Owner': 'First Owner'},
#  ...]

# %% [markdown]
# #Uploading data in Mongodb

# %%
import pymongo
from pymongo import MongoClient
#mongo client is connected
client = MongoClient()
db     = client['cardata']

# %%
rhostName = 'rs0/n1-c2-mongodb-clevercloud-customers.services.clever-cloud.com:27017,n2-c2-mongodb-clevercloud-customers.services.clever-cloud.com:27017'
ruserName = 'u6xxnzcbuooqbdjoxb1l'
rpassWord = 'Zi1ednmMWrj60RW4Ld0U'      # place your own credentials here
rdbName =  'bl49unurvjeqngy'         # place your own credentials here
rMongoURI = 'mongodb://ugaoamztcc4gww93dkqi:Zi1ednmMWrj60RW4Ld0U@n1-c2-mongodb-clevercloud-customers.services.clever-cloud.com:27017,n2-c2-mongodb-clevercloud-customers.services.clever-cloud.com:27017/bl49unurvjeqngy?replicaSet=rs0'

print(rhostName,ruserName,rdbName)
print(rMongoURI)
# Out:
# rs0/n1-c2-mongodb-clevercloud-customers.services.clever-cloud.com:27017,n2-c2-mongodb-clevercloud-customers.services.clever-cloud.com:27017 u6xxnzcbuooqbdjoxb1l bl49unurvjeqngy
# mongodb://ugaoamztcc4gww93dkqi:Zi1ednmMWrj60RW4Ld0U@n1-c2-mongodb-clevercloud-customers.services.clever-cloud.com:27017,n2-c2-mongodb-clevercloud-customers.services.clever-cloud.com:27017/bl49unurvjeqngy?replicaSet=rs0

# %%
mongoURI = rMongoURI

client = MongoClient(mongoURI)
client.list_database_names()
# Out:
# ['bl49unurvjeqngy']

# %%
db = client.bl49unurvjeqngy
db.list_collection_names()
# Out:
# ['unece', 'ausweather', 'cardekho_data', 'cardata']

# %%
table = db.cardata
table.count_documents({})
# Out:
# 4600

# %%
db.drop_collection('cardata')
# Out:
# {'ns': 'bl49unurvjeqngy.cardata',
#  'nIndexesWas': 1,
#  'ok': 1.0,
#  'operationTime': Timestamp(1688634507, 20),
#  '$clusterTime': {'clusterTime': Timestamp(1688634507, 20),
#   'signature': {'hash': b'`\xb7K&-[\x07\xd5\xb3?\xba\xe9\xe3\x84`\x957\xd2Q}',
#    'keyId': 7206532386236923905}}}

# %%
db = client.bl49unurvjeqngy
db.list_collection_names()
# Out:
# ['unece', 'ausweather', 'cardekho_data']

# %% [markdown]
# #Inserting data in Mongodb

# %%
db.cardata.insert_many(data)

# %%
db = client.bl49unurvjeqngy
db.list_collection_names()
# Out:
# ['unece', 'ausweather', 'cardekho_data', 'cardata']

# %%
xy=db.cardata

# %%
yz=db.cardata.find()

# %%
list_cursor=list(yz)

# %%
print(list_cursor)
# Out:
# [{'_id': ObjectId('64a684acbcefce4a450a2723'), 'Car_Name': 'Maruti 800 AC', 'Year': 2007, 'Selling_Price': 60000, 'Kms_Driven': 70000, 'Fuel_Type': 'Petrol', 'Seller_Type': 'Individual', 'Transmission': 'Manual', 'Owner': 'First Owner'}, {'_id': ObjectId('64a684acbcefce4a450a2724'), 'Car_Name': 'Maruti Wagon R LXI Minor', 'Year': 2007, 'Selling_Price': 135000, 'Kms_Driven': 50000, 'Fuel_Type': 'Petrol', 'Seller_Type': 'Individual', 'Transmission': 'Manual', 'Owner': 'First Owner'}, {'_id': ObjectId('64a684acbcefce4a450a2725'), 'Car_Name': 'Hyundai Verna 1.6 SX', 'Year': 2012, 'Selling_Price': 600000, 'Kms_Driven': 100000, 'Fuel_Type': 'Diesel', 'Seller_Type': 'Individual', 'Transmission': 'Manual', 'Owner': 'First Owner'}, {'_id': ObjectId('64a684acbcefce4a450a2726'), 'Car_Name': 'Datsun RediGO T Option', 'Year': 2017, 'Selling_Price': 250000, 'Kms_Driven': 46000, 'Fuel_Type': 'Petrol', 'Seller_Type': 'Individual', 'Transmission': 'Manual', 'Owner': 'First Owner'}, {'_id': ObjectId('64a684acbcefce4a450a2727'), 'Car_Name': 'Honda Amaze VX i-DTEC', 'Year': 2014, 'Selling_Price': 450000, 'Kms_Driven': 141000, 'Fuel_Type': 'Diesel', 'Seller_Type': 'Individual', 'Transmission': 'Manual', 'Owner': 'Second Owner'}, {'_id': ObjectId('64a684acbcefce4a450a2728'), 'Car_Name': 'Maruti Alto LX BSIII', 'Year': 2007, 'Selling_Price': 140000, 'Kms_Driven': 125000, 'Fuel_Type': 'Petrol', 'Seller_Type': 'Individual', 'Transmission': 'Manual', 'Owner': 'First Owner'}, {'_id': ObjectId('64a684acbcefce4a450a2729'), 'Car_Name': 'Hyundai Xcent 1.2 Kappa S', 'Year': 2016, 'Selling_Price': 550000, 'Kms_Driven': 25000, 'Fuel_Type': 'Petrol', 'Seller_Type': 'Individual', 'Transmission': 'Manual', 'Owner': 'First Owner'}, {'_id': ObjectId('64a684acbcefce4a450a272a'), 'Car_Name': 'Tata Indigo Grand Petrol', 'Year': 2014, 'Selling_Price': 240000, 'Kms_Driven': 60000, 'Fuel_Type': 'Petrol', 'Seller_Type': 'Individual', 'Transmission': 'Manual', 'Owner': 'Second Owner'}, {'_id': ObjectId('64a684acbcefce4a450a272b'), 'Car_Name': 'Hyundai Creta 1.6 VTVT S', 'Year': 2015, 'Selling_Price': 850000, 'Kms_Driven': 25000, 'Fuel_Type': 'Petrol', 'Seller_Type': 'Individual', 'Transmission': 'Manual', 'Owner': 'First Owner'}, {'_id': ObjectId('64a684acbcefce4a450a272c'), 'Car_Name': 'Maruti Celerio Green VXI', 'Year': 2017, 'Selling_Price': 365000, 'Kms_Driven': 78000, 'Fuel_Type': 'CNG', 'Seller_Type': 'Individual', 'Transmission': 'Manual', 'Owner': 'First Owner'}, {'_id': ObjectId('64a684acbcefce4a450a272d'), 'Car_Name': 'Chevrolet Sail 1.2 Base', 'Year': 2015, 'Selling_Price': 260000, 'Kms_Driven': 35000, 'Fuel_Type': 'Petrol', 'Seller_Type': 'Individual', 'Transmission': 'Manual', 'Owner': 'First Owner'}, {'_id': ObjectId('64a684acbcefce4a450a272e'), 'Car_Name': 'Tata Indigo Grand Petrol', 'Year': 2014, 'Selling_Price': 250000, 'Kms_Driven': 100000, 'Fuel_Type': 'Petrol', 'Seller_Type': 'Individual', 'Transmission': 'Manual', 'Owner': 'First Owner'}, {'_id': ObjectId('64a684acbcefce4a450a272f'), 'Car_Name': 'Toyota Corolla Altis 1.8 VL CVT', 'Year': 2018, 'Selling_Price': 1650000, 'Kms_Driven': 25000, 'Fuel_Type': 'Petrol', 'Seller_Type': 'Dealer', 'Transmission': 'Automatic', 'Owner': 'First Owner'}, {'_id': ObjectId('64a684acbcefce4a450a2730'), 'Car_Name': 'Maruti 800 AC', 'Year': 2007, 'Selling_Price': 60000, 'Kms_Driven': 70000, 'Fuel_Type': 'Petrol', 'Seller_Type': 'Individual', 'Transmission': 'Manual', 'Owner': 'First Owner'}, {'_id': ObjectId('64a684acbcefce4a450a2731'), 'Car_Name': 'Maruti Wagon R LXI Minor', 'Year': 2007, 'Selling_Price': 135000, 'Kms_Driven': 50000, 'Fuel_Type': 'Petrol', 'Seller_Type': 'Individual', 'Transmission': 'Manual', 'Owner': 'First Owner'}, {'_id': ObjectId('64a684acbcefce4a450a2732'), 'Car_Name': 'Hyundai Verna 1.6 SX', 'Year': 2012, 'Selling_Price': 600000, 'Kms_Driven': 100000, 'Fuel_Type': 'Diesel', 'Seller_Type': 'Individual', 'Transmission': 'Manual', 'Owner': 'First Owner'}, {'_id': ObjectId('64a684acbcefce4a450a2733'), ...

# %% [markdown]
# #Converting data into Pandas Dataframe

# %%
yz=pd.DataFrame(list_cursor)

# %%
yz.head()
# Out:
#                         _id                  Car_Name  Year  Selling_Price  \
# 0  64a684acbcefce4a450a2723             Maruti 800 AC  2007          60000
# 1  64a684acbcefce4a450a2724  Maruti Wagon R LXI Minor  2007         135000
# 2  64a684acbcefce4a450a2725      Hyundai Verna 1.6 SX  2012         600000
# 3  64a684acbcefce4a450a2726    Datsun RediGO T Option  2017         250000
# 4  64a684acbcefce4a450a2727     Honda Amaze VX i-DTEC  2014         450000
#
#    Kms_Driven Fuel_Type Seller_Type Transmission         Owner
# 0       70000    Petrol  Individual       Manual   First Owner
# 1       50000    Petrol  Individual       Manual   First Owner
# 2      100000    Diesel  Individual       Manual   First Owner
# 3       46000    Petrol  Individual       Manual   First Owner
# 4      141000    Diesel  Individual       Manual  Second Owner

# %% [markdown]
# #Installation of Spark

# %%
# !pip3 -q install pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('Praxis').getOrCreate()

# %%
from pyspark.sql import SparkSession
from pyspark.conf import SparkConf
from pyspark.sql.types import *
import pyspark.sql.functions as F
from pyspark.sql.functions import col, asc,desc
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from pyspark.sql import SQLContext
from pyspark.mllib.stat import Statistics
import pandas as pd
from pyspark.sql.functions import udf
from pyspark.ml.feature import OneHotEncoder, StringIndexer, VectorAssembler,StandardScaler
from pyspark.ml import Pipeline
from sklearn.metrics import confusion_matrix

# %% [markdown]
# #Converting Mongodb data to spark dataframe

# %%
ls
# Out:
# cardekho.csv  Data_Set.csv  sample_data/

# %% [markdown]
# SCHEMA FOR SPARK TABLE

# %%
schema='{"fields":[{"metadata":{},"name":"selling_price","nullable":true,"type":"long"},{"metadata":{},"name":"km_driven","nullable":true,"type":"long"},{"metadata":{},"name":"year_of_service","nullable":true,"type":"long"},{"metadata":{"ml_attr":{"name":"fuel_indexer","type":"nominal","vals":["Diesel","Petrol","CNG","LPG"]}},"name":"fuel_indexer","nullable":false,"type":"double"},{"metadata":{"ml_attr":{"attrs":{"binary":[{"idx":0,"name":"Diesel"},{"idx":1,"name":"Petrol"},{"idx":2,"name":"CNG"}]},"num_attrs":3}},"name":"fuel_Vector","nullable":true,"type":{"class":"org.apache.spark.ml.linalg.VectorUDT","pyClass":"pyspark.ml.linalg.VectorUDT","sqlType":{"fields":[{"metadata":{},"name":"type","nullable":false,"type":"byte"},{"metadata":{},"name":"size","nullable":true,"type":"integer"},{"metadata":{},"name":"indices","nullable":true,"type":{"containsNull":false,"elementType":"integer","type":"array"}},{"metadata":{},"name":"values","nullable":true,"type":{"containsNull":false,"elementType":"double","type":"array"}}],"type":"struct"},"type":"udt"}},{"metadata":{"ml_attr":{"name":"seller_type_indexer","type":"nominal","vals":["Individual","Dealer","Trustmark Dealer"]}},"name":"seller_type_indexer","nullable":false,"type":"double"},{"metadata":{"ml_attr":{"attrs":{"binary":[{"idx":0,"name":"Individual"},{"idx":1,"name":"Dealer"}]},"num_attrs":2}},"name":"seller_type_vector","nullable":true,"type":{"class":"org.apache.spark.ml.linalg.VectorUDT","pyClass":"pyspark.ml.linalg.VectorUDT","sqlType":{"fields":[{"metadata":{},"name":"type","nullable":false,"type":"byte"},{"metadata":{},"name":"size","nullable":true,"type":"integer"},{"metadata":{},"name":"indices","nullable":true,"type":{"containsNull":false,"elementType":"integer","type":"array"}},{"metadata":{},"name":"values","nullable":true,"type":{"containsNull":false,"elementType":"double","type":"array"}}],"type":"struct"},"type":"udt"}},{"metadata":{"ml_attr":{"name":"owner_indexer","type":"nominal","vals":["First Owner","Second Owner","Third Owner","Fourth & Above Owner","Test Drive Car"]}},"name":"owner_indexer","nullable":false,"type":"double"},{"metadata":{"ml_attr":{"attrs":{"binary":[{"idx":0,"name":"First Owner"},{"idx":1,"name":"Second Owner"},{"idx":2,"name":"Third Owner"},{"idx":3,"name":"Fourth & Above Owner"}]},"num_attrs":4}},"name":"owner_vector","nullable":true,"type":{"class":"org.apache.spark.ml.linalg.VectorUDT","pyClass":"pyspark.ml.linalg.VectorUDT","sqlType":{"fields":[{"metadata":{},"name":"type","nullable":false,"type":"byte"},{"metadata":{},"name":"size","nullable":true,"type":"integer"},{"metadata":{},"name":"indices","nullable":true,"type":{"containsNull":false,"elementType":"integer","type":"array"}},{"metadata":{},"name":"values","nullable":true,"type":{"containsNull":false,"elementType":"double","type":"array"}}],"type":"struct"},"type":"udt"}},{"metadata":{"ml_attr":{"name":"transmission_indexer","type":"nominal","vals":["Manual","Automatic"]}},"name":"transmission_indexer","nullable":false,"type":"double"},{"metadata":{"ml_attr":{"attrs":{"binary":[{"idx":0,"name":"Manual"}]},"num_attrs":1}},"name":"transmission_vector","nullable":true,"type":{"class":"org.apache.spark.ml.linalg.VectorUDT","pyClass":"pyspark.ml.linalg.VectorUDT","sqlType":{"fields":[{"metadata":{},"name":"type","nullable":false,"type":"byte"},{"metadata":{},"name":"size","nullable":true,"type":"integer"},{"metadata":{},"name":"indices","nullable":true,"type":{"containsNull":false,"elementType":"integer","type":"array"}},{"metadata":{},"name":"values","nullable":true,"type":{"containsNull":false,"elementType":"double","type":"array"}}],"type":"struct"},"type":"udt"}},{"metadata":{"ml_attr":{"attrs":{"binary":[{"idx":2,"name":"fuel_Vector_Diesel"},{"idx":3,"name":"fuel_Vector_Petrol"},{"idx":4,"name":"fuel_Vector_CNG"},{"idx":5,"name":"seller_type_vector_Individual"},{"idx":6,"name":"seller_type_vector_Dealer"},{"idx":7,"name":"owner_vector_First Owner"},{"idx":8,"name":"owner_vector_Second Owner"},{"idx":9,"name":"owner_vector_Third Owner"},{"idx":10,"name":"owner_vector_Fourth & Above Owner"},{"idx":11,"name":"transmission_vector_Manual"}],"numeric":[{"idx":0,"name":"km_driven"},{"idx":1,"name":"year_of_service"}]},"num_attrs":12}},"name":"features","nullable":true,"type":{"class":"org.apache.spark.ml.linalg.VectorUDT","pyClass":"pyspark.ml.linalg.VectorUDT","sqlType":{"fields":[{"metadata":{},"name":"type","nullable":false,"type":"byte"},{"metadata":{},"name":"size","nullable":true,"type":"integer"},{"metadata":{},"name":"indices","nullable":true,"type":{"containsNull":false,"elementType":"integer","type":"array"}},{"metadata":{},"name":"values","nullable":true,"type":{"containsNull":false,"elementType":"double","type":"array"}}],"type":"struct"},"type":"udt"}}],"type":"struct"}'

# %%
new_schema = StructType.fromJson(json.loads(schema))

# %% [markdown]
# #Load Data

# %%
# !wget -O Data_Set.csv -q https://github.com/Shayan007/BDNS/blob/main/cardekho.csv

# %%
# Load and Read the dataset
data=spark.read.csv('cardekho.csv',inferSchema=True,header=True)

# %%
# Chech the datatypes of the inputs
data.printSchema()
# Out:
# root
#  |-- Car_Name: string (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Selling_Price: integer (nullable = true)
#  |-- Kms_Driven: integer (nullable = true)
#  |-- Fuel_Type: string (nullable = true)
#  |-- Seller_Type: string (nullable = true)
#  |-- Transmission: string (nullable = true)
#  |-- Owner: string (nullable = true)

# %% [markdown]
# #Data Exploration

# %%
data.count(), len(data.columns)
# Out:
# (4340, 8)

# %%
data.dtypes
# Out:
# [('Car_Name', 'string'),
#  ('Year', 'int'),
#  ('Selling_Price', 'int'),
#  ('Kms_Driven', 'int'),
#  ('Fuel_Type', 'string'),
#  ('Seller_Type', 'string'),
#  ('Transmission', 'string'),
#  ('Owner', 'string')]

# %%
data.printSchema()
# Out:
# root
#  |-- Car_Name: string (nullable = true)
#  |-- Year: integer (nullable = true)
#  |-- Selling_Price: integer (nullable = true)
#  |-- Kms_Driven: integer (nullable = true)
#  |-- Fuel_Type: string (nullable = true)
#  |-- Seller_Type: string (nullable = true)
#  |-- Transmission: string (nullable = true)
#  |-- Owner: string (nullable = true)

# %%
data.count()
# Out:
# 4340

# %%
data.columns
# Out:
# ['Car_Name',
#  'Year',
#  'Selling_Price',
#  'Kms_Driven',
#  'Fuel_Type',
#  'Seller_Type',
#  'Transmission',
#  'Owner']

# %%
data.describe().show()
# Out:
# +-------+--------------------+------------------+------------------+------------------+---------+----------------+------------+-----------+
# |summary|            Car_Name|              Year|     Selling_Price|        Kms_Driven|Fuel_Type|     Seller_Type|Transmission|      Owner|
# +-------+--------------------+------------------+------------------+------------------+---------+----------------+------------+-----------+
# |  count|                4340|              4340|              4340|              4340|     4340|            4340|        4340|       4340|
# |   mean|                null|2013.0967741935483|504338.14124423964|  66195.0400921659|     null|            null|        null|       null|
# | stddev|                null| 4.215757347289534| 578544.4596037284|46649.084846457474|     null|            null|        null|       null|
# |    min|Ambassador CLASSI...|              1992|             20000|                 1|      CNG|          Dealer|   Automatic|First Owner|
# |    max|Volvo XC60 D5 Ins...|              2022|           8900000|            806599|   Petrol|Trustmark Dealer|      Manual|Third Owner|
# +-------+--------------------+------------------+------------------+------------------+---------+----------------+------------+-----------+

# %%
for col in data.columns:
  print(col, "has", data.filter(data[col].isNull()).count(), "Null values.")
# Out:
# Car_Name has 0 Null values.
# Year has 0 Null values.
# Selling_Price has 0 Null values.
# Kms_Driven has 0 Null values.
# Fuel_Type has 0 Null values.
# Seller_Type has 0 Null values.
# Transmission has 0 Null values.
# Owner has 0 Null values.

# %%
data.groupBy("Fuel_Type").count().sort("Fuel_Type").show()
# Out:
# +---------+-----+
# |Fuel_Type|count|
# +---------+-----+
# |      CNG|   40|
# |   Diesel| 2149|
# | Electric|    6|
# |      LPG|   23|
# |   Petrol| 2122|
# +---------+-----+

# %%
# Checking for the instance where the fuel is 'Electric'
data.where(data.Fuel_Type == 'Electric').show()
# Out:
# +--------------------+----+-------------+----------+---------+-----------+------------+------------+
# |            Car_Name|Year|Selling_Price|Kms_Driven|Fuel_Type|Seller_Type|Transmission|       Owner|
# +--------------------+----+-------------+----------+---------+-----------+------------+------------+
# |Maruti Swift Dzir...|2019|       650000|      5000| Electric| Individual|      Manual| First Owner|
# |    OpelCorsa 1.4 GL|2022|       950000|     10000| Electric| Individual|      Manual| First Owner|
# | Toyota Camry Hybrid|2006|       310000|     62000| Electric|     Dealer|   Automatic|Second Owner|
# |Hyundai Creta 1.6...|2021|       850000|     84000| Electric|     Dealer|      Manual| First Owner|
# |Ford Endeavour 3....|2016|      1800000|    126000| Electric|     Dealer|   Automatic| First Owner|
# |Mahindra XUV500 W...|2015|      1225000|     70000| Electric| Individual|      Manual| First Owner|
# +--------------------+----+-------------+----------+---------+-----------+------------+------------+

# %%
new_data = data.filter((data.Fuel_Type != "Electric"))

new_data.show()
# Out:
# +--------------------+----+-------------+----------+---------+-----------+------------+------------+
# |            Car_Name|Year|Selling_Price|Kms_Driven|Fuel_Type|Seller_Type|Transmission|       Owner|
# +--------------------+----+-------------+----------+---------+-----------+------------+------------+
# |       Maruti 800 AC|2007|        60000|     70000|   Petrol| Individual|      Manual| First Owner|
# |Maruti Wagon R LX...|2007|       135000|     50000|   Petrol| Individual|      Manual| First Owner|
# |Hyundai Verna 1.6 SX|2012|       600000|    100000|   Diesel| Individual|      Manual| First Owner|
# |Datsun RediGO T O...|2017|       250000|     46000|   Petrol| Individual|      Manual| First Owner|
# |Honda Amaze VX i-...|2014|       450000|    141000|   Diesel| Individual|      Manual|Second Owner|
# |Maruti Alto LX BSIII|2007|       140000|    125000|   Petrol| Individual|      Manual| First Owner|
# |Hyundai Xcent 1.2...|2016|       550000|     25000|   Petrol| Individual|      Manual| First Owner|
# |Tata Indigo Grand...|2014|       240000|     60000|   Petrol| Individual|      Manual|Second Owner|
# |Hyundai Creta 1.6...|2015|       850000|     25000|   Petrol| Individual|      Manual| First Owner|
# |Maruti Celerio Gr...|2017|       365000|     78000|      CNG| Individual|      Manual| First Owner|
# |Chevrolet Sail 1....|2015|       260000|     35000|   Petrol| Individual|      Manual| First Owner|
# |Tata Indigo Grand...|2014|       250000|    100000|   Petrol| Individual|      Manual| First Owner|
# |Toyota Corolla Al...|2018|      1650000|     25000|   Petrol|     Dealer|   Automatic| First Owner|
# |       Maruti 800 AC|2007|        60000|     70000|   Petrol| Individual|      Manual| First Owner|
# |Maruti Wagon R LX...|2007|       135000|     50000|   Petrol| Individual|      Manual| First Owner|
# |Hyundai Verna 1.6 SX|2012|       600000|    100000|   Diesel| Individual|      Manual| First Owner|
# |Datsun RediGO T O...|2017|       250000|     46000|   Petrol| Individual|      Manual| First Owner|
# |Honda Amaze VX i-...|2014|       450000|    141000|   Diesel| Individual|      Manual|Second Owner|
# |Maruti Alto LX BSIII|2007|       140000|    125000|   Petrol| Individual|      Manual| First Owner|
# |Hyundai Xcent 1.2...|2016|       550000|     25000|   Petrol| Individual|      Manual| First Owner|
# +--------------------+----+-------------+----------+---------+-----------+------------+------------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import *

# %%
new_data = new_data.withColumn("current_year",year(current_date()))
#new_data = new_data.withcolumn("")
new_data.show()
# Out:
# +--------------------+----+-------------+----------+---------+-----------+------------+------------+------------+
# |            Car_Name|Year|Selling_Price|Kms_Driven|Fuel_Type|Seller_Type|Transmission|       Owner|current_year|
# +--------------------+----+-------------+----------+---------+-----------+------------+------------+------------+
# |       Maruti 800 AC|2007|        60000|     70000|   Petrol| Individual|      Manual| First Owner|        2023|
# |Maruti Wagon R LX...|2007|       135000|     50000|   Petrol| Individual|      Manual| First Owner|        2023|
# |Hyundai Verna 1.6 SX|2012|       600000|    100000|   Diesel| Individual|      Manual| First Owner|        2023|
# |Datsun RediGO T O...|2017|       250000|     46000|   Petrol| Individual|      Manual| First Owner|        2023|
# |Honda Amaze VX i-...|2014|       450000|    141000|   Diesel| Individual|      Manual|Second Owner|        2023|
# |Maruti Alto LX BSIII|2007|       140000|    125000|   Petrol| Individual|      Manual| First Owner|        2023|
# |Hyundai Xcent 1.2...|2016|       550000|     25000|   Petrol| Individual|      Manual| First Owner|        2023|
# |Tata Indigo Grand...|2014|       240000|     60000|   Petrol| Individual|      Manual|Second Owner|        2023|
# |Hyundai Creta 1.6...|2015|       850000|     25000|   Petrol| Individual|      Manual| First Owner|        2023|
# |Maruti Celerio Gr...|2017|       365000|     78000|      CNG| Individual|      Manual| First Owner|        2023|
# |Chevrolet Sail 1....|2015|       260000|     35000|   Petrol| Individual|      Manual| First Owner|        2023|
# |Tata Indigo Grand...|2014|       250000|    100000|   Petrol| Individual|      Manual| First Owner|        2023|
# |Toyota Corolla Al...|2018|      1650000|     25000|   Petrol|     Dealer|   Automatic| First Owner|        2023|
# |       Maruti 800 AC|2007|        60000|     70000|   Petrol| Individual|      Manual| First Owner|        2023|
# |Maruti Wagon R LX...|2007|       135000|     50000|   Petrol| Individual|      Manual| First Owner|        2023|
# |Hyundai Verna 1.6 SX|2012|       600000|    100000|   Diesel| Individual|      Manual| First Owner|        2023|
# |Datsun RediGO T O...|2017|       250000|     46000|   Petrol| Individual|      Manual| First Owner|        2023|
# |Honda Amaze VX i-...|2014|       450000|    141000|   Diesel| Individual|      Manual|Second Owner|        2023|
# |Maruti Alto LX BSIII|2007|       140000|    125000|   Petrol| Individual|      Manual| First Owner|        2023|
# |Hyundai Xcent 1.2...|2016|       550000|     25000|   Petrol| Individual|      Manual| First Owner|        2023|
# +--------------------+----+-------------+----------+---------+-----------+------------+------------+------------+
# only showing top 20 rows

# %%
new_data.dtypes
# Out:
# [('Car_Name', 'string'),
#  ('Year', 'int'),
#  ('Selling_Price', 'int'),
#  ('Kms_Driven', 'int'),
#  ('Fuel_Type', 'string'),
#  ('Seller_Type', 'string'),
#  ('Transmission', 'string'),
#  ('Owner', 'string'),
#  ('current_year', 'int')]

# %%
new_data = new_data.withColumn("year_of_service",new_data.current_year - new_data.Year)
new_data.show(5)
# Out:
# +--------------------+----+-------------+----------+---------+-----------+------------+------------+------------+---------------+
# |            Car_Name|Year|Selling_Price|Kms_Driven|Fuel_Type|Seller_Type|Transmission|       Owner|current_year|year_of_service|
# +--------------------+----+-------------+----------+---------+-----------+------------+------------+------------+---------------+
# |       Maruti 800 AC|2007|        60000|     70000|   Petrol| Individual|      Manual| First Owner|        2023|             16|
# |Maruti Wagon R LX...|2007|       135000|     50000|   Petrol| Individual|      Manual| First Owner|        2023|             16|
# |Hyundai Verna 1.6 SX|2012|       600000|    100000|   Diesel| Individual|      Manual| First Owner|        2023|             11|
# |Datsun RediGO T O...|2017|       250000|     46000|   Petrol| Individual|      Manual| First Owner|        2023|              6|
# |Honda Amaze VX i-...|2014|       450000|    141000|   Diesel| Individual|      Manual|Second Owner|        2023|              9|
# +--------------------+----+-------------+----------+---------+-----------+------------+------------+------------+---------------+
# only showing top 5 rows

# %%
new_data.count(), len(new_data.columns)
# Out:
# (4334, 10)

# %%
new_data.where(new_data.Fuel_Type == 'Electric').show()
# Out:
# +--------+----+-------------+----------+---------+-----------+------------+-----+------------+---------------+
# |Car_Name|Year|Selling_Price|Kms_Driven|Fuel_Type|Seller_Type|Transmission|Owner|current_year|year_of_service|
# +--------+----+-------------+----------+---------+-----------+------------+-----+------------+---------------+
# +--------+----+-------------+----------+---------+-----------+------------+-----+------------+---------------+

# %%
new_data.groupBy("Fuel_Type").count().sort("Fuel_Type",ascending=True).show()
# Out:
# +---------+-----+
# |Fuel_Type|count|
# +---------+-----+
# |      CNG|   40|
# |   Diesel| 2149|
# |      LPG|   23|
# |   Petrol| 2122|
# +---------+-----+

# %%
new_data.groupBy("Transmission").count().sort("Transmission",ascending=True).show()
# Out:
# +------------+-----+
# |Transmission|count|
# +------------+-----+
# |   Automatic|  446|
# |      Manual| 3888|
# +------------+-----+

# %%
new_data.groupBy("Owner").count().sort("Owner",ascending=True).show()
# Out:
# +--------------------+-----+
# |               Owner|count|
# +--------------------+-----+
# |         First Owner| 2828|
# |Fourth & Above Owner|   81|
# |        Second Owner| 1105|
# |      Test Drive Car|   17|
# |         Third Owner|  303|
# +--------------------+-----+

# %%
new_data.groupBy("Car_Name").count().sort("Car_Name",ascending=True).show()
# Out:
# +--------------------+-----+
# |            Car_Name|count|
# +--------------------+-----+
# |Ambassador CLASSI...|    2|
# |Ambassador Classi...|    1|
# |Ambassador Grand ...|    1|
# |    Audi A4 1.8 TFSI|    1|
# |     Audi A4 2.0 TDI|    1|
# |Audi A4 2.0 TDI 1...|    2|
# |Audi A4 3.0 TDI Q...|   12|
# |Audi A4 30 TFSI T...|    2|
# |Audi A4 35 TDI Pr...|    1|
# |Audi A4 35 TDI Pr...|    1|
# |Audi A4 New  2.0 ...|    1|
# |   Audi A5 Sportback|    1|
# |Audi A6 2.0 TDI  ...|    3|
# |Audi A6 2.0 TDI P...|   13|
# |     Audi A6 2.7 TDI|    1|
# |     Audi A6 2.8 FSI|    1|
# |     Audi A8 4.2 TDI|    2|
# |Audi A8 L 3.0 TDI...|    1|
# |Audi Q3 2.0 TDI Q...|    4|
# |Audi Q3 35 TDI Qu...|    2|
# +--------------------+-----+
# only showing top 20 rows

# %%
new_data.groupBy('Owner').mean('Selling_price','Kms_Driven').show()
# Out:
# +--------------------+------------------+-----------------+
# |               Owner|avg(Selling_price)|  avg(Kms_Driven)|
# +--------------------+------------------+-----------------+
# |         Third Owner|270247.84488448844|99302.21122112211|
# |Fourth & Above Owner|173901.19753086418|99138.13580246913|
# |        Second Owner|343921.75927601807|81801.42262443439|
# |         First Owner| 597883.6272984442|55993.46110325318|
# |      Test Drive Car| 954293.9411764706|           4155.0|
# +--------------------+------------------+-----------------+

# %%
new_data.groupBy('Transmission').mean('Selling_Price','Kms_Driven').show()
# Out:
# +------------+------------------+-----------------+
# |Transmission|avg(Selling_Price)|  avg(Kms_Driven)|
# +------------+------------------+-----------------+
# |   Automatic|1409737.6502242154|49490.09865470852|
# |      Manual|  399768.400462963|68121.62808641975|
# +------------+------------------+-----------------+

# %%
new_data.groupBy('Fuel_Type').mean('Selling_Price','Kms_Driven').show()
# Out:
# +---------+------------------+------------------+
# |Fuel_Type|avg(Selling_Price)|   avg(Kms_Driven)|
# +---------+------------------+------------------+
# |   Diesel|   668234.02745463|  79646.5774778967|
# |      CNG|        277174.925|          67234.75|
# |      LPG|167826.04347826086| 89634.78260869565|
# |   Petrol|344986.15080113104|52317.619698397735|
# +---------+------------------+------------------+

# %%
new_data.groupBy('Year').mean('Selling_Price','Kms_Driven').show()
# Out:
# +----+------------------+------------------+
# |Year|avg(Selling_Price)|   avg(Kms_Driven)|
# +----+------------------+------------------+
# |2003| 86565.21739130435| 81671.34782608696|
# |2007|162828.35074626867| 89308.67910447762|
# |2018| 910770.4590163934|27233.784153005465|
# |2015| 526515.4749403341|60506.854415274465|
# |2006| 156403.6146788991|102976.39449541284|
# |2013| 484801.0129533679| 72728.42227979275|
# |1997|           93000.0|           90000.0|
# |2014| 523231.5640326975| 75685.27247956404|
# |2019|1061128.8350515463|           20994.5|
# |2004|121749.97619047618| 90273.30952380953|
# |1996|          225000.0|           47500.0|
# |1998|          214000.0|64583.333333333336|
# |2020|        818479.125|11037.166666666666|
# |2012| 371628.8530120482| 83393.55421686747|
# |2009|229564.73575129535| 92521.28497409326|
# |2016| 605016.8005617978| 55007.04494382023|
# |1995|           95000.0|          100000.0|
# |2001|          117649.9|          83712.85|
# |1992|           50000.0|          100000.0|
# |2005|109013.02352941176| 80991.51764705882|
# +----+------------------+------------------+
# only showing top 20 rows

# %%
new_data.groupBy('year_of_service').mean('Selling_Price','Kms_Driven').show()
# Out:
# +---------------+------------------+------------------+
# |year_of_service|avg(Selling_Price)|   avg(Kms_Driven)|
# +---------------+------------------+------------------+
# |             31|           50000.0|          100000.0|
# |             28|           95000.0|          100000.0|
# |             27|          225000.0|           47500.0|
# |             26|           93000.0|           90000.0|
# |             12|293638.33210332104| 88096.28782287824|
# |             22|          117649.9|          83712.85|
# |             13| 269678.1282051282| 91735.43589743589|
# |             16|162828.35074626867| 89308.67910447762|
# |              6|  768909.839055794| 40485.76394849786|
# |              3|        818479.125|11037.166666666666|
# |             20| 86565.21739130435| 81671.34782608696|
# |              5| 910770.4590163934|27233.784153005465|
# |             19|121749.97619047618| 90273.30952380953|
# |             15|174201.33103448275| 89163.11724137931|
# |              9| 523231.5640326975| 75685.27247956404|
# |             17| 156403.6146788991|102976.39449541284|
# |              4|1061128.8350515463|           20994.5|
# |              8| 526515.4749403341|60506.854415274465|
# |             23|           81500.0| 70936.91666666667|
# |              7| 605016.8005617978| 55007.04494382023|
# +---------------+------------------+------------------+
# only showing top 20 rows

# %%
import pandas as pd
import numpy as np

# %%
DF = new_data.toPandas()

# %%
DF.head()
# Out:
#                    Car_Name  Year  Selling_Price  Kms_Driven Fuel_Type  \
# 0             Maruti 800 AC  2007          60000       70000    Petrol
# 1  Maruti Wagon R LXI Minor  2007         135000       50000    Petrol
# 2      Hyundai Verna 1.6 SX  2012         600000      100000    Diesel
# 3    Datsun RediGO T Option  2017         250000       46000    Petrol
# 4     Honda Amaze VX i-DTEC  2014         450000      141000    Diesel
#
#   Seller_Type Transmission         Owner  current_year  year_of_service
# 0  Individual       Manual   First Owner          2023               16
# 1  Individual       Manual   First Owner          2023               16
# 2  Individual       Manual   First Owner          2023               11
# 3  Individual       Manual   First Owner          2023                6
# 4  Individual       Manual  Second Owner          2023                9

# %%
DF = DF.set_index('Car_Name')

# %%
DF.head()
# Out:
#                           year  selling_price  km_driven    fuel seller_type  \
# name
# Maruti 800 AC             2007          60000      70000  Petrol  Individual
# Maruti Wagon R LXI Minor  2007         135000      50000  Petrol  Individual
# Hyundai Verna 1.6 SX      2012         600000     100000  Diesel  Individual
# Datsun RediGO T Option    2017         250000      46000  Petrol  Individual
# Honda Amaze VX i-DTEC     2014         450000     141000  Diesel  Individual
#
#                          transmission         owner  current_year  \
# name
# Maruti 800 AC                  Manual   First Owner          2023
# Maruti Wagon R LXI Minor       Manual   First Owner          2023
# Hyundai Verna 1.6 SX           Manual   First Owner          2023
# Datsun RediGO T Option         Manual   First Owner          2023
# Honda Amaze VX i-DTEC          Manual  Second Owner          2023
#
#                           year_of_service
# name
# Maruti 800 AC                          16
# Maruti Wagon R LXI Minor               16
# Hyundai Verna 1.6 SX                   11
# Datsun RediGO T Option                  6
# Honda Amaze VX i-DTEC                   9

# %%
cor = DF.corr()
# Out:
# <ipython-input-160-53ae283c8f56>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor = DF.corr()

# %%
cor.Selling_Price.sort_values(ascending=False)
# Out:
# Selling_Price      1.000000
# Year               0.413641
# Kms_Driven        -0.193085
# year_of_service   -0.413641
# current_year            NaN
# Name: Selling_Price, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.distplot(x=DF['Kms_Driven'], bins=20, kde=True)
# Out:
# <ipython-input-164-780bb99208bf>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=DF['Kms_Driven'], bins=20, kde=True)
# <Axes: ylabel='Density'>

# %%
sns.boxplot(x='Kms_Driven',data=DF)
# Out:
# <Axes: xlabel='Kms_Driven'>

# %%
sns.boxplot(x='year_of_service', data=DF)
# Out:
# <Axes: xlabel='year_of_service'>

# %%
DF['Kms_Driven'].plot(kind='hist', bins=25)
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.regplot(x='Year', y='Selling_Price', data=DF)
# Out:
# <Axes: xlabel='Year', ylabel='Selling_Price'>

# %%
plt.figure()
DF.groupby('Year')['Selling_Price'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Year'>

# %%
sns.regplot(x='year_of_service', y='Selling_Price', data=DF)
# Out:
# <Axes: xlabel='year_of_service', ylabel='Selling_Price'>

# %%
plt.figure()
DF.groupby('year_of_service')['Selling_Price'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='year_of_service'>

# %%
sns.scatterplot(x='Kms_Driven', y='Selling_Price',data=DF )
# Out:
# <Axes: xlabel='Kms_Driven', ylabel='Selling_Price'>

# %%
plt.figure()
DF.groupby('Fuel_Type')['Selling_Price'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Fuel_Type'>

# %%
plt.figure()
DF.groupby('Owner')['Selling_Price'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Owner'>

# %%
plt.figure()
DF.groupby('Transmission')['Selling_Price'].mean().plot(kind='bar')
# Out:
# <Axes: xlabel='Transmission'>

# %%
from datetime import date

# %%
new_data.show(5)
# Out:
# +--------------------+----+-------------+----------+---------+-----------+------------+------------+------------+---------------+
# |            Car_Name|Year|Selling_Price|Kms_Driven|Fuel_Type|Seller_Type|Transmission|       Owner|current_year|year_of_service|
# +--------------------+----+-------------+----------+---------+-----------+------------+------------+------------+---------------+
# |       Maruti 800 AC|2007|        60000|     70000|   Petrol| Individual|      Manual| First Owner|        2023|             16|
# |Maruti Wagon R LX...|2007|       135000|     50000|   Petrol| Individual|      Manual| First Owner|        2023|             16|
# |Hyundai Verna 1.6 SX|2012|       600000|    100000|   Diesel| Individual|      Manual| First Owner|        2023|             11|
# |Datsun RediGO T O...|2017|       250000|     46000|   Petrol| Individual|      Manual| First Owner|        2023|              6|
# |Honda Amaze VX i-...|2014|       450000|    141000|   Diesel| Individual|      Manual|Second Owner|        2023|              9|
# +--------------------+----+-------------+----------+---------+-----------+------------+------------+------------+---------------+
# only showing top 5 rows

# %%
new_data = spark.createDataFrame(DF.rename_axis('Car_Name').reset_index() )
#spark.createDataFrame(data_clean.rename_axis('name').reset_index())

# %%
new_data.show()
# Out:
# +--------------------+----+-------------+----------+---------+-----------+------------+------------+------------+---------------+
# |            Car_Name|Year|Selling_Price|Kms_Driven|Fuel_Type|Seller_Type|Transmission|       Owner|current_year|year_of_service|
# +--------------------+----+-------------+----------+---------+-----------+------------+------------+------------+---------------+
# |       Maruti 800 AC|2007|        60000|     70000|   Petrol| Individual|      Manual| First Owner|        2023|             16|
# |Maruti Wagon R LX...|2007|       135000|     50000|   Petrol| Individual|      Manual| First Owner|        2023|             16|
# |Hyundai Verna 1.6 SX|2012|       600000|    100000|   Diesel| Individual|      Manual| First Owner|        2023|             11|
# |Datsun RediGO T O...|2017|       250000|     46000|   Petrol| Individual|      Manual| First Owner|        2023|              6|
# |Honda Amaze VX i-...|2014|       450000|    141000|   Diesel| Individual|      Manual|Second Owner|        2023|              9|
# |Maruti Alto LX BSIII|2007|       140000|    125000|   Petrol| Individual|      Manual| First Owner|        2023|             16|
# |Hyundai Xcent 1.2...|2016|       550000|     25000|   Petrol| Individual|      Manual| First Owner|        2023|              7|
# |Tata Indigo Grand...|2014|       240000|     60000|   Petrol| Individual|      Manual|Second Owner|        2023|              9|
# |Hyundai Creta 1.6...|2015|       850000|     25000|   Petrol| Individual|      Manual| First Owner|        2023|              8|
# |Maruti Celerio Gr...|2017|       365000|     78000|      CNG| Individual|      Manual| First Owner|        2023|              6|
# |Chevrolet Sail 1....|2015|       260000|     35000|   Petrol| Individual|      Manual| First Owner|        2023|              8|
# |Tata Indigo Grand...|2014|       250000|    100000|   Petrol| Individual|      Manual| First Owner|        2023|              9|
# |Toyota Corolla Al...|2018|      1650000|     25000|   Petrol|     Dealer|   Automatic| First Owner|        2023|              5|
# |       Maruti 800 AC|2007|        60000|     70000|   Petrol| Individual|      Manual| First Owner|        2023|             16|
# |Maruti Wagon R LX...|2007|       135000|     50000|   Petrol| Individual|      Manual| First Owner|        2023|             16|
# |Hyundai Verna 1.6 SX|2012|       600000|    100000|   Diesel| Individual|      Manual| First Owner|        2023|             11|
# |Datsun RediGO T O...|2017|       250000|     46000|   Petrol| Individual|      Manual| First Owner|        2023|              6|
# |Honda Amaze VX i-...|2014|       450000|    141000|   Diesel| Individual|      Manual|Second Owner|        2023|              9|
# |Maruti Alto LX BSIII|2007|       140000|    125000|   Petrol| Individual|      Manual| First Owner|        2023|             16|
# |Hyundai Xcent 1.2...|2016|       550000|     25000|   Petrol| Individual|      Manual| First Owner|        2023|              7|
# +--------------------+----+-------------+----------+---------+-----------+------------+------------+------------+---------------+
# only showing top 20 rows

# %%
new_data.select('year_of_service').distinct().rdd.map(lambda r: r[0]).collect()
# Out:
# [26,
#  19,
#  22,
#  7,
#  25,
#  6,
#  9,
#  27,
#  17,
#  28,
#  5,
#  10,
#  3,
#  12,
#  8,
#  11,
#  4,
#  13,
#  18,
#  14,
#  21,
#  15,
#  23,
#  20,
#  16,
#  24,
#  31]

# %% [markdown]
# ##Checking For Correlation

# %%
from pyspark.sql.functions import corr

# %%
new_data.corr('Kms_driven','Selling_Price')
# Out:
# -0.19308451084162284

# %%
new_data.corr('year_of_service','Selling_Price')
# Out:
# -0.41364080986190005

# %%
type(new_data)
# Out:
# pyspark.sql.dataframe.DataFrame

# %% [markdown]
# Removing Unnecessary Columns: The 'name' column doesn't seem to be necessary. So removing that. As well as the 'current_year' , 'current_date', 'year'

# %%
new_data = new_data.drop("current_date", "current_year", "Car_Name","Year")

# %%
new_data.show(5)
# Out:
# +-------------+----------+---------+-----------+------------+------------+---------------+
# |Selling_Price|Kms_Driven|Fuel_Type|Seller_Type|Transmission|       Owner|year_of_service|
# +-------------+----------+---------+-----------+------------+------------+---------------+
# |        60000|     70000|   Petrol| Individual|      Manual| First Owner|             16|
# |       135000|     50000|   Petrol| Individual|      Manual| First Owner|             16|
# |       600000|    100000|   Diesel| Individual|      Manual| First Owner|             11|
# |       250000|     46000|   Petrol| Individual|      Manual| First Owner|              6|
# |       450000|    141000|   Diesel| Individual|      Manual|Second Owner|              9|
# +-------------+----------+---------+-----------+------------+------------+---------------+
# only showing top 5 rows

# %% [markdown]
# #Data Preparation using One-Hot Encoder and Vector Assembler

# %%
from pyspark.ml.feature import StringIndexer

# %%
from pyspark.ml.feature import OneHotEncoder

# %%
from pyspark.ml.feature import VectorAssembler

# %%
type_indexer = StringIndexer(inputCol="Fuel_Type", outputCol="fuel_indexer").fit(new_data)
new_data = type_indexer.transform(new_data)

# %%
type_encoder = OneHotEncoder(inputCol="fuel_indexer", outputCol="fuel_Vector").fit(new_data)
new_data = type_encoder.transform(new_data)

# %%
type_indexer = StringIndexer(inputCol="Seller_Type", outputCol="seller_type_indexer").fit(new_data)
new_data = type_indexer.transform(new_data)

# %%
type_encoder = OneHotEncoder(inputCol="seller_type_indexer", outputCol="seller_type_vector").fit(new_data)
new_data = type_encoder.transform(new_data)

# %%
type_indexer = StringIndexer(inputCol="Owner", outputCol="owner_indexer").fit(new_data)
new_data = type_indexer.transform(new_data)

# %%
type_encoder = OneHotEncoder(inputCol="owner_indexer", outputCol="owner_vector").fit(new_data)
new_data = type_encoder.transform(new_data)

# %%
type_indexer = StringIndexer(inputCol="Transmission", outputCol="transmission_indexer").fit(new_data)
new_data = type_indexer.transform(new_data)

# %%
type_encoder = OneHotEncoder(inputCol="transmission_indexer", outputCol="transmission_vector").fit(new_data)
new_data = type_encoder.transform(new_data)

# %%
new_data.show(3)
# Out:
# +-------------+----------+---------+-----------+------------+-----------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+
# |Selling_Price|Kms_Driven|Fuel_Type|Seller_Type|Transmission|      Owner|year_of_service|fuel_indexer|  fuel_Vector|seller_type_indexer|seller_type_vector|owner_indexer| owner_vector|transmission_indexer|transmission_vector|
# +-------------+----------+---------+-----------+------------+-----------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+
# |        60000|     70000|   Petrol| Individual|      Manual|First Owner|             16|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|
# |       135000|     50000|   Petrol| Individual|      Manual|First Owner|             16|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|
# |       600000|    100000|   Diesel| Individual|      Manual|First Owner|             11|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|
# +-------------+----------+---------+-----------+------------+-----------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+
# only showing top 3 rows

# %%
new_data1 = new_data.drop("Fuel_Type","Seller_Type","Owner","Transmission")

# %%
new_data1.show(5)
# Out:
# +-------------+----------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+
# |Selling_Price|Kms_Driven|year_of_service|fuel_indexer|  fuel_Vector|seller_type_indexer|seller_type_vector|owner_indexer| owner_vector|transmission_indexer|transmission_vector|
# +-------------+----------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+
# |        60000|     70000|             16|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|
# |       135000|     50000|             16|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|
# |       600000|    100000|             11|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|
# |       250000|     46000|              6|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|
# |       450000|    141000|              9|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|
# +-------------+----------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+
# only showing top 5 rows

# %%
from pyspark.ml.linalg import DenseVector

# %%
from pyspark.ml.feature import StandardScaler

# %%
input_data = new_data.rdd.map(lambda x: (x[0], DenseVector(x[1:])))

# %%
df_assembler = VectorAssembler(inputCols=['Kms_Driven', 'year_of_service', 'fuel_Vector', 'seller_type_vector',
                                          'owner_vector', 'transmission_vector'], outputCol="features")
#df = df_assembler.transform(df)

# %%
df = df_assembler.transform(new_data1)

# %%
df.show(5)
# Out:
# +-------------+----------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+--------------------+
# |Selling_Price|Kms_Driven|year_of_service|fuel_indexer|  fuel_Vector|seller_type_indexer|seller_type_vector|owner_indexer| owner_vector|transmission_indexer|transmission_vector|            features|
# +-------------+----------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+--------------------+
# |        60000|     70000|             16|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|
# |       135000|     50000|             16|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|
# |       600000|    100000|             11|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,7,11...|
# |       250000|     46000|              6|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|
# |       450000|    141000|              9|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,8,11...|
# +-------------+----------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+--------------------+
# only showing top 5 rows

# %%
df.select(['features','selling_price']).show(5)
# Out:
# +--------------------+-------------+
# |            features|selling_price|
# +--------------------+-------------+
# |(12,[0,1,3,5,7,11...|        60000|
# |(12,[0,1,3,5,7,11...|       135000|
# |(12,[0,1,2,5,7,11...|       600000|
# |(12,[0,1,3,5,7,11...|       250000|
# |(12,[0,1,2,5,8,11...|       450000|
# +--------------------+-------------+
# only showing top 5 rows

# %% [markdown]
# #Building and Comparing ML Models

# %% [markdown]
# ##Creation and application of 2 Transformers / Estimators in a pipeline

# %%
pipeline_stages=Pipeline()\
                .setStages([type_indexer,type_encoder])
pipeline_model=pipeline_stages.fit(new_data)

# %%
from pyspark.ml.feature import StandardScaler

# %%
# Initialize the `standardScaler`
standardScaler = StandardScaler(inputCol="features", outputCol="features_scaled")

# %%
# Fit the DataFrame to the scaler
scaler = standardScaler.fit(df)

# %%
# Transform the data in `df` with the scaler
scaled_df = scaler.transform(df)

# %%
scaled_df.take(2)
# Out:
# [Row(Selling_Price=60000, Kms_Driven=70000, year_of_service=16, fuel_indexer=1.0, fuel_Vector=SparseVector(3, {1: 1.0}), seller_type_indexer=0.0, seller_type_vector=SparseVector(2, {0: 1.0}), owner_indexer=0.0, owner_vector=SparseVector(4, {0: 1.0}), transmission_indexer=0.0, transmission_vector=SparseVector(1, {0: 1.0}), features=SparseVector(12, {0: 70000.0, 1: 16.0, 3: 1.0, 5: 1.0, 7: 1.0, 11: 1.0}), features_scaled=SparseVector(12, {0: 1.5004, 1: 3.7986, 3: 2.0002, 5: 2.3024, 7: 2.0998, 11: 3.2909})),
#  Row(Selling_Price=135000, Kms_Driven=50000, year_of_service=16, fuel_indexer=1.0, fuel_Vector=SparseVector(3, {1: 1.0}), seller_type_indexer=0.0, seller_type_vector=SparseVector(2, {0: 1.0}), owner_indexer=0.0, owner_vector=SparseVector(4, {0: 1.0}), transmission_indexer=0.0, transmission_vector=SparseVector(1, {0: 1.0}), features=SparseVector(12, {0: 50000.0, 1: 16.0, 3: 1.0, 5: 1.0, 7: 1.0, 11: 1.0}), features_scaled=SparseVector(12, {0: 1.0717, 1: 3.7986, 3: 2.0002, 5: 2.3024, 7: 2.0998, 11: 3.2909}))]

# %% [markdown]
# Train-Test Split

# %%
# Split the data into train and test sets
train_data, test_data = scaled_df.randomSplit([.7,.3],seed=1234)
print("Training Dataset Count: " + str(train_data.count()))
print("Test Dataset Count: " + str(test_data.count()))
# Out:
# Training Dataset Count: 3098
# Test Dataset Count: 1236

# %%
train_data.show()
# Out:
# +-------------+----------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+--------------------+--------------------+
# |Selling_Price|Kms_Driven|year_of_service|fuel_indexer|  fuel_Vector|seller_type_indexer|seller_type_vector|owner_indexer| owner_vector|transmission_indexer|transmission_vector|            features|     features_scaled|
# +-------------+----------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+--------------------+--------------------+
# |        40000|     30000|             22|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...|
# |        40000|     40000|             25|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          3.0|(4,[3],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,10,1...|(12,[0,1,3,5,10,1...|
# |        45000|      7000|              9|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,8,11...|(12,[0,1,3,5,8,11...|
# |        45000|     72539|             22|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,8,11...|(12,[0,1,3,5,8,11...|
# |        45000|    120000|             17|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,8,11...|(12,[0,1,2,5,8,11...|
# |        50000|     35000|             25|         3.0|    (3,[],[])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,5,8,11],...|(12,[0,1,5,8,11],...|
# |        50000|     60000|             23|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...|
# |        50000|     70000|             15|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...|
# |        50000|     88500|             23|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          3.0|(4,[3],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,10,1...|(12,[0,1,3,5,10,1...|
# |        50000|    120000|             17|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          3.0|(4,[3],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,10,1...|(12,[0,1,2,5,10,1...|
# |        50000|    120000|             20|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,8,11...|(12,[0,1,2,5,8,11...|
# |        50000|    120000|             24|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,8,11...|(12,[0,1,3,5,8,11...|
# |        52000|     50000|             22|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          2.0|(4,[2],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,9,11...|(12,[0,1,3,5,9,11...|
# |        52000|     50000|             22|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          2.0|(4,[2],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,9,11...|(12,[0,1,3,5,9,11...|
# |        52000|    120000|             17|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          2.0|(4,[2],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,9,11...|(12,[0,1,3,5,9,11...|
# |        55000|     25000|             10|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          3.0|(4,[3],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,10,1...|(12,[0,1,3,5,10,1...|
# |        55000|     35000|             20|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,8,11...|(12,[0,1,2,5,8,11...|
# |        55000|     60000|             22|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          2.0|(4,[2],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,9,11...|(12,[0,1,3,5,9,11...|
# |        55000|    100000|             17|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,8,11...|(12,[0,1,2,5,8,11...|
# |        55000|    195000|             16|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          2.0|(4,[2],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,9,11...|(12,[0,1,2,5,9,11...|
# +-------------+----------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+--------------------+--------------------+
# only showing top 20 rows

# %% [markdown]
# #Training the Model

# %%
# Import `LinearRegression`
from pyspark.ml.regression import LinearRegression

# %%
# Initialize `lr`
lr = LinearRegression(labelCol="Selling_Price", maxIter=10, regParam=0.3, elasticNetParam=0.8)

# %%
# Fit the data to the model
linearModel = lr.fit(train_data)

# %%
# Generate predictions
predicted = linearModel.transform(test_data)
predicted.show()
# Out:
# +-------------+----------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+--------------------+--------------------+-------------------+
# |Selling_Price|Kms_Driven|year_of_service|fuel_indexer|  fuel_Vector|seller_type_indexer|seller_type_vector|owner_indexer| owner_vector|transmission_indexer|transmission_vector|            features|     features_scaled|         prediction|
# +-------------+----------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+--------------------+--------------------+-------------------+
# |        35000|     35000|             11|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          2.0|(4,[2],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,9,11...|(12,[0,1,3,5,9,11...| 218973.83806941542|
# |        40000|     19000|             12|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...|  240277.5329259478|
# |        43000|    100000|             22|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,8,11...|(12,[0,1,3,5,8,11...|-222141.85303402808|
# |        55000|    100000|             17|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,7,11...|(12,[0,1,2,5,7,11...|    277588.23574067|
# |        57000|     80000|             17|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,8,11...|(12,[0,1,2,5,8,11...| 259984.90423860238|
# |        58000|     27974|             10|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...| 301188.45969094685|
# |        60000|     35000|             20|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...| -53266.81638513296|
# |        60000|     35000|             24|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,8,11...|(12,[0,1,3,5,8,11...|-229180.93259000848|
# |        60000|     40000|             12|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...| 220084.96534322924|
# |        60000|     50000|             21|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...|  -102460.020933558|
# |        60000|     50000|             23|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...| -171999.9049122387|
# |        60000|    120000|             17|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          2.0|(4,[2],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,9,11...|(12,[0,1,3,5,9,11...|  -71377.6350347742|
# |        68000|    120000|             14|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,8,11...|(12,[0,1,3,5,8,11...|  36786.66613524896|
# |        69000|    100000|             15|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...|  58082.08913886896|
# |        70000|     80000|             18|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,7,11...|(12,[0,1,2,5,7,11...| 262049.31049677567|
# |        70000|     90000|             20|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,8,11...|(12,[0,1,3,5,8,11...|-142986.46068262425|
# |        70000|    110000|             17|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          2.0|(4,[2],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,9,11...|(12,[0,1,3,5,9,11...| -61762.12666205107|
# |        70000|    120000|             18|         0.0|(3,[0],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,2,5,7,11...|(12,[0,1,2,5,7,11...| 223587.27700588317|
# |        75000|     29900|             11|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          0.0|(4,[0],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,7,11...|(12,[0,1,3,5,7,11...|  264566.5707890198|
# |        75000|     35000|             11|         1.0|(3,[1],[1.0])|                0.0|     (2,[0],[1.0])|          1.0|(4,[1],[1.0])|                 0.0|      (1,[0],[1.0])|(12,[0,1,3,5,8,11...|(12,[0,1,3,5,8,11...| 222828.31327141705|
# +-------------+----------+---------------+------------+-------------+-------------------+------------------+-------------+-------------+--------------------+-------------------+--------------------+--------------------+-------------------+
# only showing top 20 rows

# %% [markdown]
# #Getting the outcome

# %%
# Coefficients for the model
linearModel.coefficients
# Out:
# DenseVector([-0.9616, -34769.942, 154033.0927, -135012.9379, -129515.2653, -123256.9055, -69536.3496, 15129.6581, -21704.6902, -25559.1654, -4432.1186, -880383.5113])

# %%
# Intercept for the model
linearModel.intercept
# Out:
# 1799309.9992582703

# %%
# Get the RMSE
linearModel.summary.rootMeanSquaredError
# Out:
# 422860.782089164

# %%
# Get the R2
linearModel.summary.r2
# Out:
# 0.45649400428868714
